# %%
# !pip install box2d-py
# !pip install stable-baselines3
# !pip install git+https://github.com/indrasweb/expert-offline-rl.git

# %%
import numpy as np
from google.colab import drive
import gym
from eorl import OfflineDataset
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import torch as T
import torch.nn as nn

from stable_baselines3.common.utils import set_random_seed
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.type_aliases import ReplayBufferSamples
from stable_baselines3.common.buffers import ReplayBuffer
from stable_baselines3 import SAC

# %%
DEVICE = T.device('cuda' if T.cuda.is_available() else 'cpu')
ENV_NAME = 'BipedalWalker-v3'
DS_NAME = 'BipedalWalker-v3'
SAVE_DIR = 'gdrive/MyDrive/SQIL/Imitation/'
ONLINE_STEPS = 5e5  # 500,000 online environment steps
EXPERT_STEPS = 1e5  # 100,000 expert steps
SEED = 1337

# %%
drive.mount('/content/gdrive/')  # model checkpoints + training stats 
set_random_seed(SEED)  # torch, np and py seeds
ds = OfflineDataset(ENV_NAME, dataset_size=EXPERT_STEPS)

if not os.path.exists(SAVE_DIR):
    os.makedirs(SAVE_DIR)
# Out:
# Mounted at /content/gdrive/

# %%
env = Monitor(gym.make(ENV_NAME), filename=SAVE_DIR+ENV_NAME)

checkpoint_callback = CheckpointCallback(
    save_freq=ONLINE_STEPS, 
    save_path=SAVE_DIR, 
    name_prefix=ENV_NAME
)

model = SAC(
    env=env,
    policy='MlpPolicy',
    learning_starts=10000,
    learning_rate=7e-4,
    buffer_size=300000,
    batch_size=256,
    train_freq=64,
    gradient_steps=64,
    gamma=0.98,
    use_sde=True,
    tau=0.02,
    verbose=1,
    policy_kwargs=dict(log_std_init=-3, net_arch=[400, 300])
)
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Using cuda device
# Wrapping the env in a DummyVecEnv.

# %%
expert_buffer = ReplayBuffer(
    100000, 
    model.replay_buffer.observation_space, 
    model.replay_buffer.action_space, 
    DEVICE
)

def populate_expert_buffer(expert_buf, expert_ds, num_samples=20000):
    batch_size = 500
    batches = num_samples // batch_size
    
    for _ in range(batches):
        obs, acts, rwds, dones, next_obs = expert_ds.batch(batch_size)        
        for i in range(batch_size):
            expert_buf.add(obs[i], next_obs[i], acts[i], rwds[i], dones[i])

# %%
def modified_replay_buffer_sample(batch_size: int, env) -> ReplayBufferSamples:
    online_samples = super(model.replay_buffer.__class__, model.replay_buffer).sample(batch_size//2, env)
    expert_samples = expert_buffer.sample(batch_size//2, env)
    obs      = T.cat((online_samples.observations, expert_samples.observations))
    actions  = T.cat((online_samples.actions, expert_samples.actions))
    next_obs = T.cat((online_samples.next_observations, expert_samples.next_observations))
    rewards  = T.cat((T.zeros_like(online_samples.rewards), T.ones_like(expert_samples.rewards)))
    dones    = T.cat((online_samples.dones, expert_samples.dones))
    
    return ReplayBufferSamples(obs, actions, next_obs, dones, rewards)

model.replay_buffer.sample = modified_replay_buffer_sample

# %%
populate_expert_buffer(expert_buffer, ds, int(EXPERT_STEPS))

# %%
model.learn(ONLINE_STEPS, log_interval=10, callback=checkpoint_callback)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 844      |
# |    ep_rew_mean     | -99.1    |
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 1834     |
# |    time_elapsed    | 4        |
# |    total timesteps | 8438     |
# | train/             |          |
# |    std             | 0.0498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 541      |
# |    ep_rew_mean     | -104     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 641      |
# |    time_elapsed    | 16       |
# |    total timesteps | 10822    |
# | train/             |          |
# |    actor_loss      | -26.5    |
# |    critic_loss     | 0.935    |
# |    ent_coef        | 0.556    |
# |    ent_coef_loss   | -3.83    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 832      |
# |    std             | 0.0501   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 404      |
# |    ep_rew_mean     | -109     |
# | time/              |          |
# |    episodes        | 30       |
# |    fps             | 348      |
# |    time_elapsed    | 34       |
# |    total timesteps | 12118    |
# | train/             |          |
# |    actor_loss      | -40.3    |
# |    critic_loss     | 2.38     |
# |    ent_coef        | 0.233    |
# |    ent_coef_loss   | -8.41    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 2112     |
# |    std             | 0.0501   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 324      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 279      |
# |    time_elapsed    | 46       |
# |    total timesteps | 12948    |
# | train/             |          |
# |    actor_loss      | -42      |
# |    critic_loss     | 2.8      |
# |    ent_coef        | 0.143    |
# |    ent_coef_loss   | -8.91    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 2944     |
# |    std             | 0.0501   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 280      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 232      |
# |    time_elapsed    | 60       |
# |    total timesteps | 13987    |
# | train/             |          |
# |    actor_loss      | -44.2    |
# |    critic_loss     | 3.58     |
# |    ent_coef        | 0.088    |
# |    ent_coef_loss   | -6.75    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 3968     |
# |    std             | 0.0501   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 272      |
# |    ep_rew_mean     | -106     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 178      |
# |    time_elapsed    | 91       |
# |    total timesteps | 16316    |
# | train/             |          |
# |    actor_loss      | -44.8    |
# |    critic_loss     | 2.55     |
# |    ent_coef        | 0.0447   |
# |    ent_coef_loss   | -1.71    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 6272     |
# |    std             | 0.0499   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 265      |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 70       |
# |    fps             | 151      |
# |    time_elapsed    | 122      |
# |    total timesteps | 18577    |
# | train/             |          |
# |    actor_loss      | -38.8    |
# |    critic_loss     | 2.68     |
# |    ent_coef        | 0.032    |
# |    ent_coef_loss   | -0.853   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 8576     |
# |    std             | 0.0499   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 277      |
# |    ep_rew_mean     | -87      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 128      |
# |    time_elapsed    | 171      |
# |    total timesteps | 22149    |
# | train/             |          |
# |    actor_loss      | -32.1    |
# |    critic_loss     | 1.22     |
# |    ent_coef        | 0.0223   |
# |    ent_coef_loss   | -0.0938  |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 12160    |
# |    std             | 0.0498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 298      |
# |    ep_rew_mean     | -66.4    |
# | time/              |          |
# |    episodes        | 90       |
# |    fps             | 114      |
# |    time_elapsed    | 235      |
# |    total timesteps | 26834    |
# | train/             |          |
# |    actor_loss      | -28.5    |
# |    critic_loss     | 1.21     |
# |    ent_coef        | 0.0271   |
# |    ent_coef_loss   | 0.116    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 16832    |
# |    std             | 0.0506   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 324      |
# |    ep_rew_mean     | -42.6    |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 104      |
# |    time_elapsed    | 310      |
# |    total timesteps | 32417    |
# | train/             |          |
# |    actor_loss      | -26.4    |
# |    critic_loss     | 1.78     |
# |    ent_coef        | 0.0303   |
# |    ent_coef_loss   | 0.0728   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 22400    |
# |    std             | 0.0517   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | -10.9    |
# | time/              |          |
# |    episodes        | 110      |
# |    fps             | 97       |
# |    time_elapsed    | 392      |
# |    total timesteps | 38403    |
# | train/             |          |
# |    actor_loss      | -23.9    |
# |    critic_loss     | 0.943    |
# |    ent_coef        | 0.0327   |
# |    ent_coef_loss   | -0.106   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 28416    |
# |    std             | 0.053    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 348      |
# |    ep_rew_mean     | 32.2     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 92       |
# |    time_elapsed    | 491      |
# |    total timesteps | 45637    |
# | train/             |          |
# |    actor_loss      | -21.3    |
# |    critic_loss     | 1.13     |
# |    ent_coef        | 0.04     |
# |    ent_coef_loss   | 0.0791   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 35648    |
# |    std             | 0.0545   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 395      |
# |    ep_rew_mean     | 68.3     |
# | time/              |          |
# |    episodes        | 130      |
# |    fps             | 90       |
# |    time_elapsed    | 573      |
# |    total timesteps | 51661    |
# | train/             |          |
# |    actor_loss      | -19.7    |
# |    critic_loss     | 1.12     |
# |    ent_coef        | 0.0394   |
# |    ent_coef_loss   | 0.0691   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 41664    |
# |    std             | 0.0557   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 452      |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 87       |
# |    time_elapsed    | 662      |
# |    total timesteps | 58183    |
# | train/             |          |
# |    actor_loss      | -18.9    |
# |    critic_loss     | 0.664    |
# |    ent_coef        | 0.0396   |
# |    ent_coef_loss   | -0.0759  |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 48192    |
# |    std             | 0.0565   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 501      |
# |    ep_rew_mean     | 143      |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 86       |
# |    time_elapsed    | 743      |
# |    total timesteps | 64111    |
# | train/             |          |
# |    actor_loss      | -17.9    |
# |    critic_loss     | 0.456    |
# |    ent_coef        | 0.0415   |
# |    ent_coef_loss   | 0.286    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 54080    |
# |    std             | 0.0573   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 535      |
# |    ep_rew_mean     | 173      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 84       |
# |    time_elapsed    | 821      |
# |    total timesteps | 69782    |
# | train/             |          |
# |    actor_loss      | -17.3    |
# |    critic_loss     | 0.796    |
# |    ent_coef        | 0.0427   |
# |    ent_coef_loss   | 0.0814   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 59776    |
# |    std             | 0.0579   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 584      |
# |    ep_rew_mean     | 211      |
# | time/              |          |
# |    episodes        | 170      |
# |    fps             | 83       |
# |    time_elapsed    | 920      |
# |    total timesteps | 76953    |
# | train/             |          |
# |    actor_loss      | -16.5    |
# |    critic_loss     | 0.846    |
# |    ent_coef        | 0.0459   |
# |    ent_coef_loss   | -0.267   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 66944    |
# |    std             | 0.0584   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 613      |
# |    ep_rew_mean     | 239      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 82       |
# |    time_elapsed    | 1007     |
# |    total timesteps | 83484    |
# | train/             |          |
# |    actor_loss      | -15.5    |
# |    critic_loss     | 0.576    |
# |    ent_coef        | 0.0479   |
# |    ent_coef_loss   | 0.108    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 73472    |
# |    std             | 0.0589   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 637      |
# |    ep_rew_mean     | 260      |
# | time/              |          |
# |    episodes        | 190      |
# |    fps             | 82       |
# |    time_elapsed    | 1102     |
# |    total timesteps | 90515    |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 0.628    |
# |    ent_coef        | 0.0521   |
# |    ent_coef_loss   | -0.217   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 80512    |
# |    std             | 0.0596   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 640      |
# |    ep_rew_mean     | 266      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 81       |
# |    time_elapsed    | 1183     |
# |    total timesteps | 96444    |
# | train/             |          |
# |    actor_loss      | -13.1    |
# |    critic_loss     | 0.568    |
# |    ent_coef        | 0.0543   |
# |    ent_coef_loss   | 0.198    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 86400    |
# |    std             | 0.06     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 646      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 210      |
# |    fps             | 80       |
# |    time_elapsed    | 1273     |
# |    total timesteps | 103051   |
# | train/             |          |
# |    actor_loss      | -11.9    |
# |    critic_loss     | 0.531    |
# |    ent_coef        | 0.0588   |
# |    ent_coef_loss   | 0.267    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 93056    |
# |    std             | 0.0605   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 633      |
# |    ep_rew_mean     | 265      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 80       |
# |    time_elapsed    | 1350     |
# |    total timesteps | 108979   |
# | train/             |          |
# |    actor_loss      | -10.5    |
# |    critic_loss     | 0.384    |
# |    ent_coef        | 0.0637   |
# |    ent_coef_loss   | 0.0683   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 98944    |
# |    std             | 0.0608   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 645      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 230      |
# |    fps             | 80       |
# |    time_elapsed    | 1446     |
# |    total timesteps | 116200   |
# | train/             |          |
# |    actor_loss      | -8.85    |
# |    critic_loss     | 0.356    |
# |    ent_coef        | 0.0681   |
# |    ent_coef_loss   | -0.22    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 106176   |
# |    std             | 0.0614   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 641      |
# |    ep_rew_mean     | 268      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 80       |
# |    time_elapsed    | 1528     |
# |    total timesteps | 122282   |
# | train/             |          |
# |    actor_loss      | -7.55    |
# |    critic_loss     | 0.311    |
# |    ent_coef        | 0.073    |
# |    ent_coef_loss   | 0.11     |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 112256   |
# |    std             | 0.0616   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 631      |
# |    ep_rew_mean     | 258      |
# | time/              |          |
# |    episodes        | 250      |
# |    fps             | 79       |
# |    time_elapsed    | 1593     |
# |    total timesteps | 127227   |
# | train/             |          |
# |    actor_loss      | -6.67    |
# |    critic_loss     | 0.298    |
# |    ent_coef        | 0.0758   |
# |    ent_coef_loss   | 0.0122   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 117184   |
# |    std             | 0.0619   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 626      |
# |    ep_rew_mean     | 253      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 79       |
# |    time_elapsed    | 1663     |
# |    total timesteps | 132373   |
# | train/             |          |
# |    actor_loss      | -5.96    |
# |    critic_loss     | 0.277    |
# |    ent_coef        | 0.0774   |
# |    ent_coef_loss   | 0.122    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 122368   |
# |    std             | 0.0622   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 614      |
# |    ep_rew_mean     | 244      |
# | time/              |          |
# |    episodes        | 270      |
# |    fps             | 79       |
# |    time_elapsed    | 1744     |
# |    total timesteps | 138337   |
# | train/             |          |
# |    actor_loss      | -4.79    |
# |    critic_loss     | 0.275    |
# |    ent_coef        | 0.0827   |
# |    ent_coef_loss   | 0.351    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 128320   |
# |    std             | 0.0625   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 613      |
# |    ep_rew_mean     | 242      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 79       |
# |    time_elapsed    | 1829     |
# |    total timesteps | 144754   |
# | train/             |          |
# |    actor_loss      | -3.91    |
# |    critic_loss     | 0.256    |
# |    ent_coef        | 0.0855   |
# |    ent_coef_loss   | 0.181    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 134720   |
# |    std             | 0.0626   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 586      |
# |    ep_rew_mean     | 222      |
# | time/              |          |
# |    episodes        | 290      |
# |    fps             | 79       |
# |    time_elapsed    | 1886     |
# |    total timesteps | 149073   |
# | train/             |          |
# |    actor_loss      | -3.2     |
# |    critic_loss     | 0.253    |
# |    ent_coef        | 0.087    |
# |    ent_coef_loss   | 0.218    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 139072   |
# |    std             | 0.0629   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 604      |
# |    ep_rew_mean     | 198      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 78       |
# |    time_elapsed    | 1989     |
# |    total timesteps | 156851   |
# | train/             |          |
# |    actor_loss      | -3.05    |
# |    critic_loss     | 0.233    |
# |    ent_coef        | 0.0862   |
# |    ent_coef_loss   | 0.148    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 146816   |
# |    std             | 0.063    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 685      |
# |    ep_rew_mean     | 160      |
# | time/              |          |
# |    episodes        | 310      |
# |    fps             | 78       |
# |    time_elapsed    | 2183     |
# |    total timesteps | 171530   |
# | train/             |          |
# |    actor_loss      | -4.4     |
# |    critic_loss     | 0.237    |
# |    ent_coef        | 0.0832   |
# |    ent_coef_loss   | 0.112    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 161536   |
# |    std             | 0.0627   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 733      |
# |    ep_rew_mean     | 126      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 78       |
# |    time_elapsed    | 2324     |
# |    total timesteps | 182267   |
# | train/             |          |
# |    actor_loss      | -5.17    |
# |    critic_loss     | 0.238    |
# |    ent_coef        | 0.0818   |
# |    ent_coef_loss   | 0.127    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 172224   |
# |    std             | 0.0623   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 783      |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 330      |
# |    fps             | 78       |
# |    time_elapsed    | 2489     |
# |    total timesteps | 194530   |
# | train/             |          |
# |    actor_loss      | -5.77    |
# |    critic_loss     | 0.236    |
# |    ent_coef        | 0.08     |
# |    ent_coef_loss   | 0.128    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 184512   |
# |    std             | 0.0619   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 841      |
# |    ep_rew_mean     | 71.7     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 77       |
# |    time_elapsed    | 2647     |
# |    total timesteps | 206365   |
# | train/             |          |
# |    actor_loss      | -6.5     |
# |    critic_loss     | 0.232    |
# |    ent_coef        | 0.0785   |
# |    ent_coef_loss   | 0.039    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 196352   |
# |    std             | 0.0614   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 897      |
# |    ep_rew_mean     | 51.6     |
# | time/              |          |
# |    episodes        | 350      |
# |    fps             | 77       |
# |    time_elapsed    | 2786     |
# |    total timesteps | 216923   |
# | train/             |          |
# |    actor_loss      | -7.18    |
# |    critic_loss     | 0.264    |
# |    ent_coef        | 0.0752   |
# |    ent_coef_loss   | 0.00221  |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 206912   |
# |    std             | 0.0608   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 986      |
# |    ep_rew_mean     | 31.4     |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 77       |
# |    time_elapsed    | 2972     |
# |    total timesteps | 230927   |
# | train/             |          |
# |    actor_loss      | -7.91    |
# |    critic_loss     | 0.258    |
# |    ent_coef        | 0.0744   |
# |    ent_coef_loss   | -0.00288 |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 220928   |
# |    std             | 0.0603   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | 22.7     |
# | time/              |          |
# |    episodes        | 370      |
# |    fps             | 77       |
# |    time_elapsed    | 3093     |
# |    total timesteps | 239898   |
# | train/             |          |
# |    actor_loss      | -7.76    |
# |    critic_loss     | 0.249    |
# |    ent_coef        | 0.0756   |
# |    ent_coef_loss   | 0.193    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 229888   |
# |    std             | 0.06     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | 20.9     |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 77       |
# |    time_elapsed    | 3181     |
# |    total timesteps | 246515   |
# | train/             |          |
# |    actor_loss      | -7.18    |
# |    critic_loss     | 0.233    |
# |    ent_coef        | 0.0773   |
# |    ent_coef_loss   | -0.224   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 236480   |
# |    std             | 0.0601   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.05e+03 |
# |    ep_rew_mean     | 43.1     |
# | time/              |          |
# |    episodes        | 390      |
# |    fps             | 77       |
# |    time_elapsed    | 3277     |
# |    total timesteps | 253700   |
# | train/             |          |
# |    actor_loss      | -6.4     |
# |    critic_loss     | 0.254    |
# |    ent_coef        | 0.0784   |
# |    ent_coef_loss   | -0.0854  |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 243712   |
# |    std             | 0.0601   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.03e+03 |
# |    ep_rew_mean     | 71.8     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 77       |
# |    time_elapsed    | 3364     |
# |    total timesteps | 260281   |
# | train/             |          |
# |    actor_loss      | -6.06    |
# |    critic_loss     | 0.209    |
# |    ent_coef        | 0.0795   |
# |    ent_coef_loss   | -0.177   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 250240   |
# |    std             | 0.0599   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 959      |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    episodes        | 410      |
# |    fps             | 77       |
# |    time_elapsed    | 3461     |
# |    total timesteps | 267471   |
# | train/             |          |
# |    actor_loss      | -5.33    |
# |    critic_loss     | 0.222    |
# |    ent_coef        | 0.0816   |
# |    ent_coef_loss   | -0.00712 |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 257472   |
# |    std             | 0.06     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 931      |
# |    ep_rew_mean     | 150      |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 77       |
# |    time_elapsed    | 3566     |
# |    total timesteps | 275377   |
# | train/             |          |
# |    actor_loss      | -4.68    |
# |    critic_loss     | 0.204    |
# |    ent_coef        | 0.082    |
# |    ent_coef_loss   | -0.04    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 265344   |
# |    std             | 0.0602   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 944      |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    episodes        | 430      |
# |    fps             | 77       |
# |    time_elapsed    | 3749     |
# |    total timesteps | 288902   |
# | train/             |          |
# |    actor_loss      | -5.29    |
# |    critic_loss     | 0.226    |
# |    ent_coef        | 0.0804   |
# |    ent_coef_loss   | -0.033   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 278912   |
# |    std             | 0.0597   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 967      |
# |    ep_rew_mean     | 133      |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 76       |
# |    time_elapsed    | 3938     |
# |    total timesteps | 303110   |
# | train/             |          |
# |    actor_loss      | -5.76    |
# |    critic_loss     | 0.202    |
# |    ent_coef        | 0.0782   |
# |    ent_coef_loss   | -0.0588  |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 293120   |
# |    std             | 0.0592   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 989      |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    episodes        | 450      |
# |    fps             | 76       |
# |    time_elapsed    | 4106     |
# |    total timesteps | 315789   |
# | train/             |          |
# |    actor_loss      | -5.44    |
# |    critic_loss     | 0.202    |
# |    ent_coef        | 0.0795   |
# |    ent_coef_loss   | 0.0956   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 305792   |
# |    std             | 0.0587   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 967      |
# |    ep_rew_mean     | 128      |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 76       |
# |    time_elapsed    | 4265     |
# |    total timesteps | 327668   |
# | train/             |          |
# |    actor_loss      | -5.35    |
# |    critic_loss     | 0.185    |
# |    ent_coef        | 0.0805   |
# |    ent_coef_loss   | 0.15     |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 317632   |
# |    std             | 0.058    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+03 |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 470      |
# |    fps             | 76       |
# |    time_elapsed    | 4439     |
# |    total timesteps | 340603   |
# | train/             |          |
# |    actor_loss      | -5.51    |
# |    critic_loss     | 0.184    |
# |    ent_coef        | 0.0794   |
# |    ent_coef_loss   | 0.0371   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 330560   |
# |    std             | 0.0571   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 69.8     |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 76       |
# |    time_elapsed    | 4568     |
# |    total timesteps | 350050   |
# | train/             |          |
# |    actor_loss      | -6.09    |
# |    critic_loss     | 0.19     |
# |    ent_coef        | 0.0775   |
# |    ent_coef_loss   | -0.221   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 340032   |
# |    std             | 0.0561   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.07e+03 |
# |    ep_rew_mean     | 32.6     |
# | time/              |          |
# |    episodes        | 490      |
# |    fps             | 76       |
# |    time_elapsed    | 4712     |
# |    total timesteps | 360743   |
# | train/             |          |
# |    actor_loss      | -6.68    |
# |    critic_loss     | 0.194    |
# |    ent_coef        | 0.0735   |
# |    ent_coef_loss   | -0.284   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 350720   |
# |    std             | 0.0549   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -5.87    |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 76       |
# |    time_elapsed    | 4864     |
# |    total timesteps | 372068   |
# | train/             |          |
# |    actor_loss      | -7.46    |
# |    critic_loss     | 0.184    |
# |    ent_coef        | 0.0701   |
# |    ent_coef_loss   | 0.0436   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 362048   |
# |    std             | 0.0538   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.15e+03 |
# |    ep_rew_mean     | -41.5    |
# | time/              |          |
# |    episodes        | 510      |
# |    fps             | 76       |
# |    time_elapsed    | 4996     |
# |    total timesteps | 382101   |
# | train/             |          |
# |    actor_loss      | -8.47    |
# |    critic_loss     | 0.235    |
# |    ent_coef        | 0.0657   |
# |    ent_coef_loss   | -0.0047  |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 372096   |
# |    std             | 0.0525   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.16e+03 |
# |    ep_rew_mean     | -61.2    |
# | time/              |          |
# |    episodes        | 520      |
# |    fps             | 76       |
# |    time_elapsed    | 5124     |
# |    total timesteps | 391743   |
# | train/             |          |
# |    actor_loss      | -9.06    |
# |    critic_loss     | 0.267    |
# |    ent_coef        | 0.063    |
# |    ent_coef_loss   | -0.0354  |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 381696   |
# |    std             | 0.0514   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.16e+03 |
# |    ep_rew_mean     | -43.4    |
# | time/              |          |
# |    episodes        | 530      |
# |    fps             | 76       |
# |    time_elapsed    | 5300     |
# |    total timesteps | 404827   |
# | train/             |          |
# |    actor_loss      | -10.5    |
# |    critic_loss     | 0.267    |
# |    ent_coef        | 0.0584   |
# |    ent_coef_loss   | -0.00779 |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 394816   |
# |    std             | 0.0501   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | -5.79    |
# | time/              |          |
# |    episodes        | 540      |
# |    fps             | 76       |
# |    time_elapsed    | 5395     |
# |    total timesteps | 411941   |
# | train/             |          |
# |    actor_loss      | -10.3    |
# |    critic_loss     | 0.299    |
# |    ent_coef        | 0.0574   |
# |    ent_coef_loss   | 0.151    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 401920   |
# |    std             | 0.0497   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.03e+03 |
# |    ep_rew_mean     | 33.7     |
# | time/              |          |
# |    episodes        | 550      |
# |    fps             | 76       |
# |    time_elapsed    | 5491     |
# |    total timesteps | 419084   |
# | train/             |          |
# |    actor_loss      | -10.3    |
# |    critic_loss     | 0.301    |
# |    ent_coef        | 0.0564   |
# |    ent_coef_loss   | 0.0614   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 409088   |
# |    std             | 0.0492   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 986      |
# |    ep_rew_mean     | 73       |
# | time/              |          |
# |    episodes        | 560      |
# |    fps             | 76       |
# |    time_elapsed    | 5587     |
# |    total timesteps | 426237   |
# | train/             |          |
# |    actor_loss      | -10.1    |
# |    critic_loss     | 0.234    |
# |    ent_coef        | 0.0566   |
# |    ent_coef_loss   | 0.137    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 416192   |
# |    std             | 0.049    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 928      |
# |    ep_rew_mean     | 116      |
# | time/              |          |
# |    episodes        | 570      |
# |    fps             | 76       |
# |    time_elapsed    | 5684     |
# |    total timesteps | 433382   |
# | train/             |          |
# |    actor_loss      | -10      |
# |    critic_loss     | 0.228    |
# |    ent_coef        | 0.0573   |
# |    ent_coef_loss   | -0.0648  |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 423360   |
# |    std             | 0.0489   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 857      |
# |    ep_rew_mean     | 118      |
# | time/              |          |
# |    episodes        | 580      |
# |    fps             | 76       |
# |    time_elapsed    | 5717     |
# |    total timesteps | 435792   |
# | train/             |          |
# |    actor_loss      | -15.4    |
# |    critic_loss     | 1.41     |
# |    ent_coef        | 0.0268   |
# |    ent_coef_loss   | -3.25    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 425792   |
# |    std             | 0.0486   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 760      |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 590      |
# |    fps             | 76       |
# |    time_elapsed    | 5728     |
# |    total timesteps | 436699   |
# | train/             |          |
# |    actor_loss      | -17.5    |
# |    critic_loss     | 0.867    |
# |    ent_coef        | 0.0223   |
# |    ent_coef_loss   | 1.27     |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 426688   |
# |    std             | 0.0479   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 707      |
# |    ep_rew_mean     | 148      |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 76       |
# |    time_elapsed    | 5811     |
# |    total timesteps | 442746   |
# | train/             |          |
# |    actor_loss      | -14.2    |
# |    critic_loss     | 0.7      |
# |    ent_coef        | 0.0451   |
# |    ent_coef_loss   | -0.105   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 432704   |
# |    std             | 0.0479   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 678      |
# |    ep_rew_mean     | 184      |
# | time/              |          |
# |    episodes        | 610      |
# |    fps             | 76       |
# |    time_elapsed    | 5906     |
# |    total timesteps | 449854   |
# | train/             |          |
# |    actor_loss      | -12.5    |
# |    critic_loss     | 0.355    |
# |    ent_coef        | 0.0484   |
# |    ent_coef_loss   | -0.00949 |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 439808   |
# |    std             | 0.048    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 653      |
# |    ep_rew_mean     | 209      |
# | time/              |          |
# |    episodes        | 620      |
# |    fps             | 76       |
# |    time_elapsed    | 6003     |
# |    total timesteps | 457017   |
# | train/             |          |
# |    actor_loss      | -12      |
# |    critic_loss     | 0.364    |
# |    ent_coef        | 0.0515   |
# |    ent_coef_loss   | 0.0992   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 446976   |
# |    std             | 0.048    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 590      |
# |    ep_rew_mean     | 231      |
# | time/              |          |
# |    episodes        | 630      |
# |    fps             | 76       |
# |    time_elapsed    | 6095     |
# |    total timesteps | 463828   |
# | train/             |          |
# |    actor_loss      | -10.4    |
# |    critic_loss     | 0.269    |
# |    ent_coef        | 0.0551   |
# |    ent_coef_loss   | -0.0153  |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 453824   |
# |    std             | 0.048    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 590      |
# |    ep_rew_mean     | 231      |
# | time/              |          |
# |    episodes        | 640      |
# |    fps             | 76       |
# |    time_elapsed    | 6192     |
# |    total timesteps | 470977   |
# | train/             |          |
# |    actor_loss      | -8.45    |
# |    critic_loss     | 0.246    |
# |    ent_coef        | 0.0613   |
# |    ent_coef_loss   | -0.275   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 460992   |
# |    std             | 0.0483   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 587      |
# |    ep_rew_mean     | 228      |
# | time/              |          |
# |    episodes        | 650      |
# |    fps             | 76       |
# |    time_elapsed    | 6284     |
# |    total timesteps | 477794   |
# | train/             |          |
# |    actor_loss      | -6.31    |
# |    critic_loss     | 0.203    |
# |    ent_coef        | 0.0694   |
# |    ent_coef_loss   | -0.12    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 467776   |
# |    std             | 0.0486   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 587      |
# |    ep_rew_mean     | 228      |
# | time/              |          |
# |    episodes        | 660      |
# |    fps             | 75       |
# |    time_elapsed    | 6382     |
# |    total timesteps | 484982   |
# | train/             |          |
# |    actor_loss      | -4.33    |
# |    critic_loss     | 0.187    |
# |    ent_coef        | 0.0773   |
# |    ent_coef_loss   | 0.164    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 474944   |
# |    std             | 0.0492   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 579      |
# |    ep_rew_mean     | 198      |
# | time/              |          |
# |    episodes        | 670      |
# |    fps             | 75       |
# |    time_elapsed    | 6468     |
# |    total timesteps | 491329   |
# | train/             |          |
# |    actor_loss      | -3.37    |
# |    critic_loss     | 0.19     |
# |    ent_coef        | 0.0779   |
# |    ent_coef_loss   | 0.00165  |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 481344   |
# |    std             | 0.0494   |
# ---------------------------------

# %%
 def plot_log(df_path):

    with open(df_path, "rt") as f:
        _ = f.readline()
        df = pd.read_csv(f)
        df.sort_values("t", inplace=True)
        df.reset_index(inplace=True)

    # compute rolling avg and std
    sma_y = df['r'].rolling(100).mean()
    std_y = df['r'].rolling(100).std()
    
    # plot with seaborn
    sns.set()
    fig, ax = plt.subplots(figsize=(10,10))
    ax.set_xlabel('Timesteps')
    ax.set_ylabel('Reward')
    clrs = sns.color_palette("husl", 8)

    true_x = (ONLINE_STEPS // max(df['index'])) * df['index']

    # fill standard deviation
    ax.plot(true_x, sma_y, c=clrs[0])
    ax.fill_between(true_x, sma_y-std_y,  sma_y+std_y, 
                    alpha=0.3, facecolor=clrs[0]) 
    plt.savefig(SAVE_DIR+ENV_NAME+'.reward_history.png', 
                dpi=300, pad_inches=0)
    plt.show()

plot_log(SAVE_DIR+ENV_NAME+'.monitor.csv')
