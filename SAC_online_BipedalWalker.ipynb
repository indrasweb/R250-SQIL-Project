# %%
# !pip install box2d-py
# !pip install stable-baselines3

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive
import pandas as pd
import pickle as pkl
import gym
import os

import torch as T
import torch.nn as nn

from stable_baselines3.common.utils import set_random_seed
from stable_baselines3.common.monitor import Monitor, load_results
from stable_baselines3.common.vec_env import VecFrameStack, VecNormalize, VecTransposeImage
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.type_aliases import ReplayBufferSamples
from stable_baselines3.common.buffers import ReplayBuffer
from stable_baselines3 import SAC

# %%
DEVICE = T.device('cuda' if T.cuda.is_available() else 'cpu')
ENV_NAME = 'BipedalWalker-v3'
SAVE_DIR = 'gdrive/MyDrive/SQIL/Online/'
ONLINE_STEPS = 5e5    # 500,000 online environment steps
SEED = 1337

# %%
drive.mount('/content/gdrive/')  # model checkpoints + training stats 
set_random_seed(SEED)  # torch, np and py seeds

if not os.path.exists(SAVE_DIR):
    os.makedirs(SAVE_DIR)
# Out:
# Mounted at /content/gdrive/

# %%
env = Monitor(gym.make(ENV_NAME), filename=SAVE_DIR+ENV_NAME)

checkpoint_callback = CheckpointCallback(
    save_freq=ONLINE_STEPS, 
    save_path=SAVE_DIR, 
    name_prefix=ENV_NAME
)

model = SAC(
    env=env,
    policy='MlpPolicy',
    learning_starts=10000,
    learning_rate=7e-4,
    buffer_size=300000,
    batch_size=256,
    train_freq=64,
    gradient_steps=64,
    gamma=0.98,
    use_sde=True,
    tau=0.02,
    verbose=1,
    policy_kwargs=dict(log_std_init=-3, net_arch=[400, 300])
)

# hyperparams https://github.com/DLR-RM/rl-baselines3-zoo/blob/master/hyperparams/sac.yml
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Using cuda device
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(ONLINE_STEPS, log_interval=10, callback=checkpoint_callback)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 526      |
# |    ep_rew_mean     | -100     |
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 1735     |
# |    time_elapsed    | 3        |
# |    total timesteps | 5255     |
# | train/             |          |
# |    std             | 0.0498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 378      |
# |    ep_rew_mean     | -104     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 1746     |
# |    time_elapsed    | 4        |
# |    total timesteps | 7565     |
# | train/             |          |
# |    std             | 0.0498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 350      |
# |    ep_rew_mean     | -107     |
# | time/              |          |
# |    episodes        | 30       |
# |    fps             | 852      |
# |    time_elapsed    | 12       |
# |    total timesteps | 10499    |
# | train/             |          |
# |    actor_loss      | -11.6    |
# |    critic_loss     | 18.4     |
# |    ent_coef        | 0.698    |
# |    ent_coef_loss   | -2.35    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 512      |
# |    std             | 0.05     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 298      |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 392      |
# |    time_elapsed    | 30       |
# |    total timesteps | 11922    |
# | train/             |          |
# |    actor_loss      | -23      |
# |    critic_loss     | 2.63     |
# |    ent_coef        | 0.263    |
# |    ent_coef_loss   | -8.3     |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 1920     |
# |    std             | 0.05     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 265      |
# |    ep_rew_mean     | -112     |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 281      |
# |    time_elapsed    | 47       |
# |    total timesteps | 13248    |
# | train/             |          |
# |    actor_loss      | -17.3    |
# |    critic_loss     | 2.4      |
# |    ent_coef        | 0.114    |
# |    ent_coef_loss   | -10.8    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 3200     |
# |    std             | 0.0498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 315      |
# |    ep_rew_mean     | -113     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 157      |
# |    time_elapsed    | 120      |
# |    total timesteps | 18910    |
# | train/             |          |
# |    actor_loss      | 0.316    |
# |    critic_loss     | 0.224    |
# |    ent_coef        | 0.00477  |
# |    ent_coef_loss   | -8.76    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 8896     |
# |    std             | 0.048    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 340      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 70       |
# |    fps             | 129      |
# |    time_elapsed    | 183      |
# |    total timesteps | 23765    |
# | train/             |          |
# |    actor_loss      | 3.39     |
# |    critic_loss     | 0.71     |
# |    ent_coef        | 0.00161  |
# |    ent_coef_loss   | -3.27    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 13760    |
# |    std             | 0.046    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 469      |
# |    ep_rew_mean     | -106     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 103      |
# |    time_elapsed    | 361      |
# |    total timesteps | 37536    |
# | train/             |          |
# |    actor_loss      | 2.66     |
# |    critic_loss     | 0.793    |
# |    ent_coef        | 0.00148  |
# |    ent_coef_loss   | -0.422   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 27520    |
# |    std             | 0.0428   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 533      |
# |    ep_rew_mean     | -102     |
# | time/              |          |
# |    episodes        | 90       |
# |    fps             | 96       |
# |    time_elapsed    | 495      |
# |    total timesteps | 47940    |
# | train/             |          |
# |    actor_loss      | 2.48     |
# |    critic_loss     | 0.197    |
# |    ent_coef        | 0.00176  |
# |    ent_coef_loss   | 0.0725   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 37952    |
# |    std             | 0.0416   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 579      |
# |    ep_rew_mean     | -98.8    |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 92       |
# |    time_elapsed    | 623      |
# |    total timesteps | 57855    |
# | train/             |          |
# |    actor_loss      | 2.74     |
# |    critic_loss     | 0.262    |
# |    ent_coef        | 0.00176  |
# |    ent_coef_loss   | -0.546   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 47808    |
# |    std             | 0.0406   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 658      |
# |    ep_rew_mean     | -93.5    |
# | time/              |          |
# |    episodes        | 110      |
# |    fps             | 89       |
# |    time_elapsed    | 793      |
# |    total timesteps | 71041    |
# | train/             |          |
# |    actor_loss      | 2.32     |
# |    critic_loss     | 0.599    |
# |    ent_coef        | 0.00137  |
# |    ent_coef_loss   | 0.909    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 61056    |
# |    std             | 0.0395   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 738      |
# |    ep_rew_mean     | -88.2    |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 87       |
# |    time_elapsed    | 925      |
# |    total timesteps | 81336    |
# | train/             |          |
# |    actor_loss      | 2.03     |
# |    critic_loss     | 0.053    |
# |    ent_coef        | 0.00149  |
# |    ent_coef_loss   | -2.69    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 71296    |
# |    std             | 0.0387   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 815      |
# |    ep_rew_mean     | -82.4    |
# | time/              |          |
# |    episodes        | 130      |
# |    fps             | 86       |
# |    time_elapsed    | 1061     |
# |    total timesteps | 91999    |
# | train/             |          |
# |    actor_loss      | 2.02     |
# |    critic_loss     | 0.0635   |
# |    ent_coef        | 0.00151  |
# |    ent_coef_loss   | -0.602   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 81984    |
# |    std             | 0.0384   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 916      |
# |    ep_rew_mean     | -74      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 85       |
# |    time_elapsed    | 1211     |
# |    total timesteps | 103563   |
# | train/             |          |
# |    actor_loss      | 1.94     |
# |    critic_loss     | 0.625    |
# |    ent_coef        | 0.00157  |
# |    ent_coef_loss   | -0.36    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 93568    |
# |    std             | 0.0379   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | -65.8    |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 84       |
# |    time_elapsed    | 1365     |
# |    total timesteps | 115472   |
# | train/             |          |
# |    actor_loss      | 1.61     |
# |    critic_loss     | 0.0904   |
# |    ent_coef        | 0.00163  |
# |    ent_coef_loss   | -3.68    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 105472   |
# |    std             | 0.0375   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | -58.1    |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 83       |
# |    time_elapsed    | 1526     |
# |    total timesteps | 127936   |
# | train/             |          |
# |    actor_loss      | 1.5      |
# |    critic_loss     | 0.108    |
# |    ent_coef        | 0.00165  |
# |    ent_coef_loss   | 0.0567   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 117888   |
# |    std             | 0.0373   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -49.5    |
# | time/              |          |
# |    episodes        | 170      |
# |    fps             | 83       |
# |    time_elapsed    | 1703     |
# |    total timesteps | 141618   |
# | train/             |          |
# |    actor_loss      | 1.31     |
# |    critic_loss     | 0.0584   |
# |    ent_coef        | 0.0021   |
# |    ent_coef_loss   | 0.554    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 131584   |
# |    std             | 0.0381   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -44      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 82       |
# |    time_elapsed    | 1891     |
# |    total timesteps | 156084   |
# | train/             |          |
# |    actor_loss      | 0.952    |
# |    critic_loss     | 0.0822   |
# |    ent_coef        | 0.00246  |
# |    ent_coef_loss   | -0.0445  |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 146048   |
# |    std             | 0.0378   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.21e+03 |
# |    ep_rew_mean     | -38.8    |
# | time/              |          |
# |    episodes        | 190      |
# |    fps             | 82       |
# |    time_elapsed    | 2058     |
# |    total timesteps | 168938   |
# | train/             |          |
# |    actor_loss      | 0.622    |
# |    critic_loss     | 0.0852   |
# |    ent_coef        | 0.00257  |
# |    ent_coef_loss   | 1.02     |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 158912   |
# |    std             | 0.0376   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.26e+03 |
# |    ep_rew_mean     | -29.8    |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 81       |
# |    time_elapsed    | 2247     |
# |    total timesteps | 183409   |
# | train/             |          |
# |    actor_loss      | 0.195    |
# |    critic_loss     | 0.0644   |
# |    ent_coef        | 0.0024   |
# |    ent_coef_loss   | -0.115   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 173376   |
# |    std             | 0.0377   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.25e+03 |
# |    ep_rew_mean     | -9.37    |
# | time/              |          |
# |    episodes        | 210      |
# |    fps             | 81       |
# |    time_elapsed    | 2417     |
# |    total timesteps | 196340   |
# | train/             |          |
# |    actor_loss      | -0.515   |
# |    critic_loss     | 0.0868   |
# |    ent_coef        | 0.00281  |
# |    ent_coef_loss   | 0.889    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 186304   |
# |    std             | 0.0376   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.25e+03 |
# |    ep_rew_mean     | 6.61     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 80       |
# |    time_elapsed    | 2548     |
# |    total timesteps | 206396   |
# | train/             |          |
# |    actor_loss      | -0.872   |
# |    critic_loss     | 0.109    |
# |    ent_coef        | 0.00282  |
# |    ent_coef_loss   | 0.337    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 196352   |
# |    std             | 0.0378   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.25e+03 |
# |    ep_rew_mean     | 35.9     |
# | time/              |          |
# |    episodes        | 230      |
# |    fps             | 80       |
# |    time_elapsed    | 2684     |
# |    total timesteps | 216812   |
# | train/             |          |
# |    actor_loss      | -1.85    |
# |    critic_loss     | 0.102    |
# |    ent_coef        | 0.00341  |
# |    ent_coef_loss   | 0.635    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 206784   |
# |    std             | 0.0384   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.22e+03 |
# |    ep_rew_mean     | 63.8     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 80       |
# |    time_elapsed    | 2801     |
# |    total timesteps | 225688   |
# | train/             |          |
# |    actor_loss      | -2.81    |
# |    critic_loss     | 0.122    |
# |    ent_coef        | 0.00466  |
# |    ent_coef_loss   | 0.753    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 215680   |
# |    std             | 0.0389   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | 88.2     |
# | time/              |          |
# |    episodes        | 250      |
# |    fps             | 80       |
# |    time_elapsed    | 2892     |
# |    total timesteps | 232682   |
# | train/             |          |
# |    actor_loss      | -3.32    |
# |    critic_loss     | 0.131    |
# |    ent_coef        | 0.00526  |
# |    ent_coef_loss   | -0.655   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 222656   |
# |    std             | 0.0394   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 122      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 80       |
# |    time_elapsed    | 3004     |
# |    total timesteps | 241271   |
# | train/             |          |
# |    actor_loss      | -4.07    |
# |    critic_loss     | 0.33     |
# |    ent_coef        | 0.00607  |
# |    ent_coef_loss   | 0.202    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 231232   |
# |    std             | 0.0402   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.08e+03 |
# |    ep_rew_mean     | 152      |
# | time/              |          |
# |    episodes        | 270      |
# |    fps             | 80       |
# |    time_elapsed    | 3109     |
# |    total timesteps | 249237   |
# | train/             |          |
# |    actor_loss      | -4.87    |
# |    critic_loss     | 0.561    |
# |    ent_coef        | 0.00603  |
# |    ent_coef_loss   | -0.536   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 239232   |
# |    std             | 0.0402   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+03 |
# |    ep_rew_mean     | 182      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 80       |
# |    time_elapsed    | 3212     |
# |    total timesteps | 257155   |
# | train/             |          |
# |    actor_loss      | -5.41    |
# |    critic_loss     | 0.38     |
# |    ent_coef        | 0.00528  |
# |    ent_coef_loss   | 0.815    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 247168   |
# |    std             | 0.0402   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 962      |
# |    ep_rew_mean     | 215      |
# | time/              |          |
# |    episodes        | 290      |
# |    fps             | 79       |
# |    time_elapsed    | 3315     |
# |    total timesteps | 265097   |
# | train/             |          |
# |    actor_loss      | -5.8     |
# |    critic_loss     | 0.151    |
# |    ent_coef        | 0.00538  |
# |    ent_coef_loss   | 0.416    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 255104   |
# |    std             | 0.0404   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 896      |
# |    ep_rew_mean     | 244      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 79       |
# |    time_elapsed    | 3419     |
# |    total timesteps | 272972   |
# | train/             |          |
# |    actor_loss      | -6.03    |
# |    critic_loss     | 0.315    |
# |    ent_coef        | 0.00602  |
# |    ent_coef_loss   | 0.0226   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 262976   |
# |    std             | 0.0408   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 834      |
# |    ep_rew_mean     | 252      |
# | time/              |          |
# |    episodes        | 310      |
# |    fps             | 79       |
# |    time_elapsed    | 3507     |
# |    total timesteps | 279761   |
# | train/             |          |
# |    actor_loss      | -6.42    |
# |    critic_loss     | 0.174    |
# |    ent_coef        | 0.0054   |
# |    ent_coef_loss   | -0.52    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 269760   |
# |    std             | 0.0407   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 812      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 79       |
# |    time_elapsed    | 3608     |
# |    total timesteps | 287562   |
# | train/             |          |
# |    actor_loss      | -6.83    |
# |    critic_loss     | 0.207    |
# |    ent_coef        | 0.0067   |
# |    ent_coef_loss   | -1.16    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 277568   |
# |    std             | 0.0409   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 783      |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 330      |
# |    fps             | 79       |
# |    time_elapsed    | 3707     |
# |    total timesteps | 295153   |
# | train/             |          |
# |    actor_loss      | -6.96    |
# |    critic_loss     | 0.14     |
# |    ent_coef        | 0.00619  |
# |    ent_coef_loss   | 0.245    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 285120   |
# |    std             | 0.0411   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 765      |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 79       |
# |    time_elapsed    | 3800     |
# |    total timesteps | 302182   |
# | train/             |          |
# |    actor_loss      | -7.27    |
# |    critic_loss     | 0.186    |
# |    ent_coef        | 0.00652  |
# |    ent_coef_loss   | -0.507   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 292160   |
# |    std             | 0.041    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 772      |
# |    ep_rew_mean     | 287      |
# | time/              |          |
# |    episodes        | 350      |
# |    fps             | 79       |
# |    time_elapsed    | 3900     |
# |    total timesteps | 309883   |
# | train/             |          |
# |    actor_loss      | -8.09    |
# |    critic_loss     | 0.287    |
# |    ent_coef        | 0.00612  |
# |    ent_coef_loss   | -0.324   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 299840   |
# |    std             | 0.0406   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 760      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 79       |
# |    time_elapsed    | 3998     |
# |    total timesteps | 317304   |
# | train/             |          |
# |    actor_loss      | -8.97    |
# |    critic_loss     | 0.304    |
# |    ent_coef        | 0.00638  |
# |    ent_coef_loss   | -0.311   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 307264   |
# |    std             | 0.0409   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 752      |
# |    ep_rew_mean     | 282      |
# | time/              |          |
# |    episodes        | 370      |
# |    fps             | 79       |
# |    time_elapsed    | 4093     |
# |    total timesteps | 324456   |
# | train/             |          |
# |    actor_loss      | -9.33    |
# |    critic_loss     | 0.341    |
# |    ent_coef        | 0.00525  |
# |    ent_coef_loss   | 0.443    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 314432   |
# |    std             | 0.0407   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 733      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 79       |
# |    time_elapsed    | 4170     |
# |    total timesteps | 330464   |
# | train/             |          |
# |    actor_loss      | -9.57    |
# |    critic_loss     | 0.282    |
# |    ent_coef        | 0.00568  |
# |    ent_coef_loss   | 0.625    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 320448   |
# |    std             | 0.0408   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 724      |
# |    ep_rew_mean     | 268      |
# | time/              |          |
# |    episodes        | 390      |
# |    fps             | 79       |
# |    time_elapsed    | 4262     |
# |    total timesteps | 337520   |
# | train/             |          |
# |    actor_loss      | -9.88    |
# |    critic_loss     | 0.327    |
# |    ent_coef        | 0.0062   |
# |    ent_coef_loss   | 0.192    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 327488   |
# |    std             | 0.0407   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 720      |
# |    ep_rew_mean     | 266      |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 79       |
# |    time_elapsed    | 4359     |
# |    total timesteps | 344973   |
# | train/             |          |
# |    actor_loss      | -10.2    |
# |    critic_loss     | 0.258    |
# |    ent_coef        | 0.0058   |
# |    ent_coef_loss   | -0.0317  |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 334976   |
# |    std             | 0.0406   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 729      |
# |    ep_rew_mean     | 274      |
# | time/              |          |
# |    episodes        | 410      |
# |    fps             | 79       |
# |    time_elapsed    | 4459     |
# |    total timesteps | 352633   |
# | train/             |          |
# |    actor_loss      | -10.8    |
# |    critic_loss     | 0.193    |
# |    ent_coef        | 0.00555  |
# |    ent_coef_loss   | -0.699   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 342592   |
# |    std             | 0.0406   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 724      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 79       |
# |    time_elapsed    | 4554     |
# |    total timesteps | 359981   |
# | train/             |          |
# |    actor_loss      | -11.2    |
# |    critic_loss     | 0.308    |
# |    ent_coef        | 0.00565  |
# |    ent_coef_loss   | -0.37    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 349952   |
# |    std             | 0.0408   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 722      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 430      |
# |    fps             | 78       |
# |    time_elapsed    | 4651     |
# |    total timesteps | 367339   |
# | train/             |          |
# |    actor_loss      | -12      |
# |    critic_loss     | 0.402    |
# |    ent_coef        | 0.00621  |
# |    ent_coef_loss   | -0.133   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 357312   |
# |    std             | 0.0406   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 728      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 78       |
# |    time_elapsed    | 4749     |
# |    total timesteps | 374975   |
# | train/             |          |
# |    actor_loss      | -12.6    |
# |    critic_loss     | 0.217    |
# |    ent_coef        | 0.00702  |
# |    ent_coef_loss   | 0.177    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 364928   |
# |    std             | 0.0408   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 721      |
# |    ep_rew_mean     | 278      |
# | time/              |          |
# |    episodes        | 450      |
# |    fps             | 78       |
# |    time_elapsed    | 4841     |
# |    total timesteps | 382023   |
# | train/             |          |
# |    actor_loss      | -12.9    |
# |    critic_loss     | 0.242    |
# |    ent_coef        | 0.00556  |
# |    ent_coef_loss   | 0.348    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 372032   |
# |    std             | 0.0404   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 706      |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 78       |
# |    time_elapsed    | 4918     |
# |    total timesteps | 387921   |
# | train/             |          |
# |    actor_loss      | -13      |
# |    critic_loss     | 0.269    |
# |    ent_coef        | 0.0056   |
# |    ent_coef_loss   | -0.165   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 377920   |
# |    std             | 0.0405   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 700      |
# |    ep_rew_mean     | 270      |
# | time/              |          |
# |    episodes        | 470      |
# |    fps             | 78       |
# |    time_elapsed    | 5002     |
# |    total timesteps | 394469   |
# | train/             |          |
# |    actor_loss      | -13.5    |
# |    critic_loss     | 0.3      |
# |    ent_coef        | 0.00633  |
# |    ent_coef_loss   | -0.603   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 384448   |
# |    std             | 0.0406   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 716      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 78       |
# |    time_elapsed    | 5102     |
# |    total timesteps | 402078   |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 0.352    |
# |    ent_coef        | 0.00601  |
# |    ent_coef_loss   | 0.714    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 392064   |
# |    std             | 0.0406   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 720      |
# |    ep_rew_mean     | 289      |
# | time/              |          |
# |    episodes        | 490      |
# |    fps             | 78       |
# |    time_elapsed    | 5200     |
# |    total timesteps | 409561   |
# | train/             |          |
# |    actor_loss      | -14.5    |
# |    critic_loss     | 0.505    |
# |    ent_coef        | 0.00569  |
# |    ent_coef_loss   | 0.611    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 399552   |
# |    std             | 0.0406   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 717      |
# |    ep_rew_mean     | 288      |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 78       |
# |    time_elapsed    | 5292     |
# |    total timesteps | 416708   |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 0.419    |
# |    ent_coef        | 0.00584  |
# |    ent_coef_loss   | 0.134    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 406720   |
# |    std             | 0.0406   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 715      |
# |    ep_rew_mean     | 289      |
# | time/              |          |
# |    episodes        | 510      |
# |    fps             | 78       |
# |    time_elapsed    | 5388     |
# |    total timesteps | 424088   |
# | train/             |          |
# |    actor_loss      | -15.2    |
# |    critic_loss     | 0.301    |
# |    ent_coef        | 0.00598  |
# |    ent_coef_loss   | 0.583    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 414080   |
# |    std             | 0.0405   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 707      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 520      |
# |    fps             | 78       |
# |    time_elapsed    | 5475     |
# |    total timesteps | 430730   |
# | train/             |          |
# |    actor_loss      | -15.5    |
# |    critic_loss     | 0.445    |
# |    ent_coef        | 0.00597  |
# |    ent_coef_loss   | -0.858   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 420736   |
# |    std             | 0.0406   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 707      |
# |    ep_rew_mean     | 289      |
# | time/              |          |
# |    episodes        | 530      |
# |    fps             | 78       |
# |    time_elapsed    | 5570     |
# |    total timesteps | 438065   |
# | train/             |          |
# |    actor_loss      | -16.1    |
# |    critic_loss     | 0.442    |
# |    ent_coef        | 0.00542  |
# |    ent_coef_loss   | -0.681   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 428032   |
# |    std             | 0.0404   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 704      |
# |    ep_rew_mean     | 289      |
# | time/              |          |
# |    episodes        | 540      |
# |    fps             | 78       |
# |    time_elapsed    | 5666     |
# |    total timesteps | 445362   |
# | train/             |          |
# |    actor_loss      | -16.4    |
# |    critic_loss     | 0.516    |
# |    ent_coef        | 0.00541  |
# |    ent_coef_loss   | 0.257    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 435328   |
# |    std             | 0.0402   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 705      |
# |    ep_rew_mean     | 291      |
# | time/              |          |
# |    episodes        | 550      |
# |    fps             | 78       |
# |    time_elapsed    | 5758     |
# |    total timesteps | 452498   |
# | train/             |          |
# |    actor_loss      | -16.7    |
# |    critic_loss     | 0.625    |
# |    ent_coef        | 0.00556  |
# |    ent_coef_loss   | -0.353   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 442496   |
# |    std             | 0.0402   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 718      |
# |    ep_rew_mean     | 302      |
# | time/              |          |
# |    episodes        | 560      |
# |    fps             | 78       |
# |    time_elapsed    | 5853     |
# |    total timesteps | 459752   |
# | train/             |          |
# |    actor_loss      | -17.3    |
# |    critic_loss     | 0.581    |
# |    ent_coef        | 0.00537  |
# |    ent_coef_loss   | -0.183   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 449728   |
# |    std             | 0.0401   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 721      |
# |    ep_rew_mean     | 306      |
# | time/              |          |
# |    episodes        | 570      |
# |    fps             | 78       |
# |    time_elapsed    | 5943     |
# |    total timesteps | 466614   |
# | train/             |          |
# |    actor_loss      | -17.6    |
# |    critic_loss     | 0.549    |
# |    ent_coef        | 0.00542  |
# |    ent_coef_loss   | -0.0497  |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 456576   |
# |    std             | 0.0401   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 717      |
# |    ep_rew_mean     | 306      |
# | time/              |          |
# |    episodes        | 580      |
# |    fps             | 78       |
# |    time_elapsed    | 6036     |
# |    total timesteps | 473738   |
# | train/             |          |
# |    actor_loss      | -18.1    |
# |    critic_loss     | 0.603    |
# |    ent_coef        | 0.00566  |
# |    ent_coef_loss   | -0.918   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 463744   |
# |    std             | 0.04     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 711      |
# |    ep_rew_mean     | 302      |
# | time/              |          |
# |    episodes        | 590      |
# |    fps             | 78       |
# |    time_elapsed    | 6127     |
# |    total timesteps | 480701   |
# | train/             |          |
# |    actor_loss      | -18.3    |
# |    critic_loss     | 0.402    |
# |    ent_coef        | 0.00539  |
# |    ent_coef_loss   | 0.777    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 470656   |
# |    std             | 0.0399   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 712      |
# |    ep_rew_mean     | 305      |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 78       |
# |    time_elapsed    | 6220     |
# |    total timesteps | 487869   |
# | train/             |          |
# |    actor_loss      | -18.5    |
# |    critic_loss     | 0.721    |
# |    ent_coef        | 0.00536  |
# |    ent_coef_loss   | -0.123   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 477824   |
# |    std             | 0.0399   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 707      |
# |    ep_rew_mean     | 303      |
# | time/              |          |
# |    episodes        | 610      |
# |    fps             | 78       |
# |    time_elapsed    | 6311     |
# |    total timesteps | 494769   |
# | train/             |          |
# |    actor_loss      | -18.8    |
# |    critic_loss     | 0.561    |
# |    ent_coef        | 0.00567  |
# |    ent_coef_loss   | 0.253    |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 484736   |
# |    std             | 0.0397   |
# ---------------------------------

# %%
def plot_log(df_path):
    
    with open(df_path, "rt") as f:
        _ = f.readline()
        df = pd.read_csv(f)
        df.sort_values("t", inplace=True)
        df.reset_index(inplace=True)

    # compute rolling avg and std
    sma_y = df['r'].rolling(100).mean()
    std_y = df['r'].rolling(100).std()
    
    # plot with seaborn
    sns.set()
    fig, ax = plt.subplots(figsize=(10,10))
    ax.set_xlabel('Timesteps')
    ax.set_ylabel('Reward')
    clrs = sns.color_palette("husl", 8)

    true_x = (ONLINE_STEPS // max(df['index'])) * df['index']

    # fill standard deviation
    ax.plot(true_x, sma_y, c=clrs[0])
    ax.fill_between(true_x, sma_y-std_y,  sma_y+std_y, 
                    alpha=0.3, facecolor=clrs[0]) 
    plt.savefig(SAVE_DIR+ENV_NAME+'.reward_history.png', 
                dpi=300, pad_inches=0)
    plt.show()

plot_log(SAVE_DIR+ENV_NAME+'.monitor.csv')

# %%
def get_expert_buf(num=100000):
    buf = {'observation':[], 'action':[], 'terminal':[], 'reward':[]}
    obs = env.reset()
    for _ in range(num):
        action, _states = model.predict(obs)
        buf['observation'].append(obs)
        buf['action'].append(action)
        obs, reward, done, info = env.step(action)
        buf['terminal'].append(done)
        buf['reward'].append(reward)
        if done:
            obs = env.reset()
    buf['observation'] = np.stack(buf['observation'])
    buf['action'] = np.stack(buf['action'])
    buf['reward'] = np.stack(buf['reward'])
    
    return buf

expert_data = get_expert_buf()
with open(SAVE_DIR+ENV_NAME+'.expert_data.pkl', 'wb') as f:
    pkl.dump(expert_data, f)
