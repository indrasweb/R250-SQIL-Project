# %%
# !pip install box2d-py
# !pip install stable-baselines3

# %%
import numpy as np
from google.colab import drive
import seaborn as sns
import matplotlib.pyplot as plt
import pickle as pkl
import pandas as pd
import gym
import os

import torch as T
import torch.nn as nn

from stable_baselines3.common.utils import set_random_seed
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import VecFrameStack, VecNormalize, VecTransposeImage
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.type_aliases import ReplayBufferSamples
from stable_baselines3.common.buffers import ReplayBuffer
from stable_baselines3 import SAC

# %%
DEVICE = T.device('cuda' if T.cuda.is_available() else 'cpu')
ENV_NAME = 'LunarLanderContinuous-v2'
SAVE_DIR = 'gdrive/MyDrive/SQIL/Online/'
ONLINE_STEPS = 5e5    # 500,000 online environment steps
SEED = 1337

# %%
drive.mount('/content/gdrive/')  # model checkpoints + training stats 
set_random_seed(SEED)  # torch, np and py seeds

if not os.path.exists(SAVE_DIR):
    os.makedirs(SAVE_DIR)
# Out:
# Mounted at /content/gdrive/

# %%
env = Monitor(gym.make(ENV_NAME), filename=SAVE_DIR+ENV_NAME)

checkpoint_callback = CheckpointCallback(
    save_freq=ONLINE_STEPS, 
    save_path=SAVE_DIR, 
    name_prefix=ENV_NAME
)

model = SAC(
    env=env,
    policy='MlpPolicy',
    learning_starts=1000,
    batch_size=256,
    verbose=1
)
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(ONLINE_STEPS, log_interval=10, callback=checkpoint_callback)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 113      |
# |    ep_rew_mean     | -181     |
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 496      |
# |    time_elapsed    | 2        |
# |    total timesteps | 1131     |
# | train/             |          |
# |    actor_loss      | -1.21    |
# |    critic_loss     | 175      |
# |    ent_coef        | 0.962    |
# |    ent_coef_loss   | -0.122   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 130      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 140      |
# |    ep_rew_mean     | -238     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 129      |
# |    time_elapsed    | 21       |
# |    total timesteps | 2808     |
# | train/             |          |
# |    actor_loss      | 4.14     |
# |    critic_loss     | 3.13     |
# |    ent_coef        | 0.603    |
# |    ent_coef_loss   | -1.22    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1807     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 371      |
# |    ep_rew_mean     | -172     |
# | time/              |          |
# |    episodes        | 30       |
# |    fps             | 82       |
# |    time_elapsed    | 135      |
# |    total timesteps | 11133    |
# | train/             |          |
# |    actor_loss      | -9.33    |
# |    critic_loss     | 11.2     |
# |    ent_coef        | 0.0778   |
# |    ent_coef_loss   | -1.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10132    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 450      |
# |    ep_rew_mean     | -158     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 79       |
# |    time_elapsed    | 226      |
# |    total timesteps | 17992    |
# | train/             |          |
# |    actor_loss      | -12      |
# |    critic_loss     | 49.5     |
# |    ent_coef        | 0.0696   |
# |    ent_coef_loss   | -0.577   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16991    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 525      |
# |    ep_rew_mean     | -135     |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 77       |
# |    time_elapsed    | 340      |
# |    total timesteps | 26270    |
# | train/             |          |
# |    actor_loss      | -18.2    |
# |    critic_loss     | 4.17     |
# |    ent_coef        | 0.0828   |
# |    ent_coef_loss   | 0.412    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25269    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 590      |
# |    ep_rew_mean     | -116     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 75       |
# |    time_elapsed    | 466      |
# |    total timesteps | 35377    |
# | train/             |          |
# |    actor_loss      | -17.4    |
# |    critic_loss     | 14.4     |
# |    ent_coef        | 0.0609   |
# |    ent_coef_loss   | 0.435    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 34376    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 630      |
# |    ep_rew_mean     | -100     |
# | time/              |          |
# |    episodes        | 70       |
# |    fps             | 75       |
# |    time_elapsed    | 584      |
# |    total timesteps | 44076    |
# | train/             |          |
# |    actor_loss      | -11.2    |
# |    critic_loss     | 29.5     |
# |    ent_coef        | 0.0481   |
# |    ent_coef_loss   | 1.07     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43075    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 635      |
# |    ep_rew_mean     | -83.5    |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 75       |
# |    time_elapsed    | 673      |
# |    total timesteps | 50813    |
# | train/             |          |
# |    actor_loss      | -16.7    |
# |    critic_loss     | 2.63     |
# |    ent_coef        | 0.0712   |
# |    ent_coef_loss   | 0.304    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49812    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 594      |
# |    ep_rew_mean     | -72      |
# | time/              |          |
# |    episodes        | 90       |
# |    fps             | 75       |
# |    time_elapsed    | 705      |
# |    total timesteps | 53504    |
# | train/             |          |
# |    actor_loss      | -19.6    |
# |    critic_loss     | 6.92     |
# |    ent_coef        | 0.065    |
# |    ent_coef_loss   | -0.325   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 52503    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 599      |
# |    ep_rew_mean     | -56      |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 76       |
# |    time_elapsed    | 786      |
# |    total timesteps | 59910    |
# | train/             |          |
# |    actor_loss      | -20.5    |
# |    critic_loss     | 3.37     |
# |    ent_coef        | 0.0845   |
# |    ent_coef_loss   | 0.498    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 58909    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 655      |
# |    ep_rew_mean     | -31.5    |
# | time/              |          |
# |    episodes        | 110      |
# |    fps             | 76       |
# |    time_elapsed    | 871      |
# |    total timesteps | 66603    |
# | train/             |          |
# |    actor_loss      | -18.8    |
# |    critic_loss     | 1.58     |
# |    ent_coef        | 0.0667   |
# |    ent_coef_loss   | -0.124   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 65602    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 702      |
# |    ep_rew_mean     | 8.31     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 76       |
# |    time_elapsed    | 952      |
# |    total timesteps | 72990    |
# | train/             |          |
# |    actor_loss      | -19.4    |
# |    critic_loss     | 1.51     |
# |    ent_coef        | 0.0586   |
# |    ent_coef_loss   | 0.385    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 71989    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 657      |
# |    ep_rew_mean     | 26.8     |
# | time/              |          |
# |    episodes        | 130      |
# |    fps             | 76       |
# |    time_elapsed    | 999      |
# |    total timesteps | 76837    |
# | train/             |          |
# |    actor_loss      | -17      |
# |    critic_loss     | 19       |
# |    ent_coef        | 0.0578   |
# |    ent_coef_loss   | 0.339    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 75836    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 627      |
# |    ep_rew_mean     | 57.4     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 77       |
# |    time_elapsed    | 1047     |
# |    total timesteps | 80676    |
# | train/             |          |
# |    actor_loss      | -20.9    |
# |    critic_loss     | 4.82     |
# |    ent_coef        | 0.0529   |
# |    ent_coef_loss   | 0.0285   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 79675    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 590      |
# |    ep_rew_mean     | 64.5     |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 77       |
# |    time_elapsed    | 1106     |
# |    total timesteps | 85264    |
# | train/             |          |
# |    actor_loss      | -23.2    |
# |    critic_loss     | 4.7      |
# |    ent_coef        | 0.0531   |
# |    ent_coef_loss   | 0.972    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 84263    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 536      |
# |    ep_rew_mean     | 59.2     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 77       |
# |    time_elapsed    | 1153     |
# |    total timesteps | 88974    |
# | train/             |          |
# |    actor_loss      | -20.4    |
# |    critic_loss     | 7.8      |
# |    ent_coef        | 0.0607   |
# |    ent_coef_loss   | -0.395   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 87973    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 510      |
# |    ep_rew_mean     | 65.3     |
# | time/              |          |
# |    episodes        | 170      |
# |    fps             | 77       |
# |    time_elapsed    | 1229     |
# |    total timesteps | 95055    |
# | train/             |          |
# |    actor_loss      | -19.5    |
# |    critic_loss     | 5.55     |
# |    ent_coef        | 0.0597   |
# |    ent_coef_loss   | 0.0685   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 94054    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 76.1     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 77       |
# |    time_elapsed    | 1304     |
# |    total timesteps | 100791   |
# | train/             |          |
# |    actor_loss      | -20.4    |
# |    critic_loss     | 3.09     |
# |    ent_coef        | 0.0571   |
# |    ent_coef_loss   | -0.764   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99790    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 515      |
# |    ep_rew_mean     | 98.2     |
# | time/              |          |
# |    episodes        | 190      |
# |    fps             | 77       |
# |    time_elapsed    | 1355     |
# |    total timesteps | 104977   |
# | train/             |          |
# |    actor_loss      | -20.4    |
# |    critic_loss     | 5.81     |
# |    ent_coef        | 0.0547   |
# |    ent_coef_loss   | 0.148    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 103976   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 486      |
# |    ep_rew_mean     | 115      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 77       |
# |    time_elapsed    | 1398     |
# |    total timesteps | 108524   |
# | train/             |          |
# |    actor_loss      | -26.6    |
# |    critic_loss     | 2.43     |
# |    ent_coef        | 0.0721   |
# |    ent_coef_loss   | 0.156    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 107523   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 465      |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    episodes        | 210      |
# |    fps             | 77       |
# |    time_elapsed    | 1454     |
# |    total timesteps | 113072   |
# | train/             |          |
# |    actor_loss      | -30      |
# |    critic_loss     | 6.27     |
# |    ent_coef        | 0.0851   |
# |    ent_coef_loss   | 0.553    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 112071   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 445      |
# |    ep_rew_mean     | 145      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 77       |
# |    time_elapsed    | 1508     |
# |    total timesteps | 117508   |
# | train/             |          |
# |    actor_loss      | -35.4    |
# |    critic_loss     | 4.38     |
# |    ent_coef        | 0.0903   |
# |    ent_coef_loss   | -0.33    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 116507   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 448      |
# |    ep_rew_mean     | 155      |
# | time/              |          |
# |    episodes        | 230      |
# |    fps             | 77       |
# |    time_elapsed    | 1560     |
# |    total timesteps | 121653   |
# | train/             |          |
# |    actor_loss      | -39      |
# |    critic_loss     | 6.8      |
# |    ent_coef        | 0.085    |
# |    ent_coef_loss   | 0.428    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 120652   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 444      |
# |    ep_rew_mean     | 161      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 78       |
# |    time_elapsed    | 1601     |
# |    total timesteps | 125122   |
# | train/             |          |
# |    actor_loss      | -41.5    |
# |    critic_loss     | 3.32     |
# |    ent_coef        | 0.0774   |
# |    ent_coef_loss   | 0.0851   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 124121   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 428      |
# |    ep_rew_mean     | 180      |
# | time/              |          |
# |    episodes        | 250      |
# |    fps             | 78       |
# |    time_elapsed    | 1636     |
# |    total timesteps | 128086   |
# | train/             |          |
# |    actor_loss      | -44.1    |
# |    critic_loss     | 11.6     |
# |    ent_coef        | 0.0759   |
# |    ent_coef_loss   | 0.276    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 127085   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 419      |
# |    ep_rew_mean     | 207      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 78       |
# |    time_elapsed    | 1668     |
# |    total timesteps | 130841   |
# | train/             |          |
# |    actor_loss      | -41.8    |
# |    critic_loss     | 4.52     |
# |    ent_coef        | 0.0706   |
# |    ent_coef_loss   | -0.334   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 129840   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 385      |
# |    ep_rew_mean     | 223      |
# | time/              |          |
# |    episodes        | 270      |
# |    fps             | 78       |
# |    time_elapsed    | 1701     |
# |    total timesteps | 133552   |
# | train/             |          |
# |    actor_loss      | -41.7    |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.0633   |
# |    ent_coef_loss   | 0.538    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 132551   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 354      |
# |    ep_rew_mean     | 225      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 78       |
# |    time_elapsed    | 1732     |
# |    total timesteps | 136199   |
# | train/             |          |
# |    actor_loss      | -44.7    |
# |    critic_loss     | 25.8     |
# |    ent_coef        | 0.0681   |
# |    ent_coef_loss   | 0.593    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 135198   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 338      |
# |    ep_rew_mean     | 220      |
# | time/              |          |
# |    episodes        | 290      |
# |    fps             | 78       |
# |    time_elapsed    | 1762     |
# |    total timesteps | 138760   |
# | train/             |          |
# |    actor_loss      | -41.2    |
# |    critic_loss     | 12.6     |
# |    ent_coef        | 0.0766   |
# |    ent_coef_loss   | 0.122    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 137759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 327      |
# |    ep_rew_mean     | 209      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 78       |
# |    time_elapsed    | 1791     |
# |    total timesteps | 141227   |
# | train/             |          |
# |    actor_loss      | -39.8    |
# |    critic_loss     | 17.9     |
# |    ent_coef        | 0.0797   |
# |    ent_coef_loss   | 0.156    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 140226   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 308      |
# |    ep_rew_mean     | 208      |
# | time/              |          |
# |    episodes        | 310      |
# |    fps             | 78       |
# |    time_elapsed    | 1822     |
# |    total timesteps | 143858   |
# | train/             |          |
# |    actor_loss      | -43.3    |
# |    critic_loss     | 5.26     |
# |    ent_coef        | 0.0815   |
# |    ent_coef_loss   | 0.286    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 142857   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 286      |
# |    ep_rew_mean     | 204      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 79       |
# |    time_elapsed    | 1849     |
# |    total timesteps | 146134   |
# | train/             |          |
# |    actor_loss      | -42.7    |
# |    critic_loss     | 7.75     |
# |    ent_coef        | 0.0839   |
# |    ent_coef_loss   | -0.0156  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 145133   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 274      |
# |    ep_rew_mean     | 197      |
# | time/              |          |
# |    episodes        | 330      |
# |    fps             | 79       |
# |    time_elapsed    | 1883     |
# |    total timesteps | 149008   |
# | train/             |          |
# |    actor_loss      | -48      |
# |    critic_loss     | 8.05     |
# |    ent_coef        | 0.084    |
# |    ent_coef_loss   | 0.583    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 148007   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 275      |
# |    ep_rew_mean     | 198      |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 79       |
# |    time_elapsed    | 1927     |
# |    total timesteps | 152648   |
# | train/             |          |
# |    actor_loss      | -49.5    |
# |    critic_loss     | 13.3     |
# |    ent_coef        | 0.0787   |
# |    ent_coef_loss   | -0.409   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 151647   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 271      |
# |    ep_rew_mean     | 198      |
# | time/              |          |
# |    episodes        | 350      |
# |    fps             | 79       |
# |    time_elapsed    | 1956     |
# |    total timesteps | 155152   |
# | train/             |          |
# |    actor_loss      | -49.3    |
# |    critic_loss     | 3.32     |
# |    ent_coef        | 0.0833   |
# |    ent_coef_loss   | -0.152   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 154151   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 275      |
# |    ep_rew_mean     | 202      |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 79       |
# |    time_elapsed    | 1994     |
# |    total timesteps | 158312   |
# | train/             |          |
# |    actor_loss      | -44.5    |
# |    critic_loss     | 2.52     |
# |    ent_coef        | 0.0793   |
# |    ent_coef_loss   | 0.99     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 157311   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 281      |
# |    ep_rew_mean     | 205      |
# | time/              |          |
# |    episodes        | 370      |
# |    fps             | 79       |
# |    time_elapsed    | 2034     |
# |    total timesteps | 161647   |
# | train/             |          |
# |    actor_loss      | -48.4    |
# |    critic_loss     | 5.2      |
# |    ent_coef        | 0.0787   |
# |    ent_coef_loss   | -0.0949  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 160646   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 284      |
# |    ep_rew_mean     | 213      |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 79       |
# |    time_elapsed    | 2070     |
# |    total timesteps | 164577   |
# | train/             |          |
# |    actor_loss      | -44.1    |
# |    critic_loss     | 8.48     |
# |    ent_coef        | 0.0759   |
# |    ent_coef_loss   | -0.00493 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 163576   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 286      |
# |    ep_rew_mean     | 220      |
# | time/              |          |
# |    episodes        | 390      |
# |    fps             | 79       |
# |    time_elapsed    | 2103     |
# |    total timesteps | 167361   |
# | train/             |          |
# |    actor_loss      | -44.4    |
# |    critic_loss     | 2.93     |
# |    ent_coef        | 0.0773   |
# |    ent_coef_loss   | -0.298   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 166360   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 286      |
# |    ep_rew_mean     | 232      |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 79       |
# |    time_elapsed    | 2132     |
# |    total timesteps | 169830   |
# | train/             |          |
# |    actor_loss      | -45.3    |
# |    critic_loss     | 2.81     |
# |    ent_coef        | 0.0753   |
# |    ent_coef_loss   | -0.609   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 168829   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 291      |
# |    ep_rew_mean     | 234      |
# | time/              |          |
# |    episodes        | 410      |
# |    fps             | 79       |
# |    time_elapsed    | 2168     |
# |    total timesteps | 172921   |
# | train/             |          |
# |    actor_loss      | -48.9    |
# |    critic_loss     | 6.81     |
# |    ent_coef        | 0.0677   |
# |    ent_coef_loss   | -0.0672  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 171920   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 293      |
# |    ep_rew_mean     | 240      |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 79       |
# |    time_elapsed    | 2198     |
# |    total timesteps | 175412   |
# | train/             |          |
# |    actor_loss      | -50.9    |
# |    critic_loss     | 2.38     |
# |    ent_coef        | 0.0676   |
# |    ent_coef_loss   | -0.0968  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 174411   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 292      |
# |    ep_rew_mean     | 249      |
# | time/              |          |
# |    episodes        | 430      |
# |    fps             | 79       |
# |    time_elapsed    | 2231     |
# |    total timesteps | 178218   |
# | train/             |          |
# |    actor_loss      | -48.8    |
# |    critic_loss     | 6.96     |
# |    ent_coef        | 0.0681   |
# |    ent_coef_loss   | -0.0364  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 177217   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 282      |
# |    ep_rew_mean     | 240      |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 79       |
# |    time_elapsed    | 2261     |
# |    total timesteps | 180852   |
# | train/             |          |
# |    actor_loss      | -50.9    |
# |    critic_loss     | 11.1     |
# |    ent_coef        | 0.0709   |
# |    ent_coef_loss   | 0.811    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 179851   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 283      |
# |    ep_rew_mean     | 243      |
# | time/              |          |
# |    episodes        | 450      |
# |    fps             | 80       |
# |    time_elapsed    | 2292     |
# |    total timesteps | 183417   |
# | train/             |          |
# |    actor_loss      | -53.8    |
# |    critic_loss     | 3.44     |
# |    ent_coef        | 0.0721   |
# |    ent_coef_loss   | -0.763   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 182416   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 282      |
# |    ep_rew_mean     | 243      |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 80       |
# |    time_elapsed    | 2330     |
# |    total timesteps | 186549   |
# | train/             |          |
# |    actor_loss      | -48.2    |
# |    critic_loss     | 5.28     |
# |    ent_coef        | 0.0735   |
# |    ent_coef_loss   | 0.773    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 185548   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 275      |
# |    ep_rew_mean     | 238      |
# | time/              |          |
# |    episodes        | 470      |
# |    fps             | 80       |
# |    time_elapsed    | 2360     |
# |    total timesteps | 189106   |
# | train/             |          |
# |    actor_loss      | -50      |
# |    critic_loss     | 11.2     |
# |    ent_coef        | 0.0667   |
# |    ent_coef_loss   | 0.614    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 188105   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 274      |
# |    ep_rew_mean     | 236      |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 80       |
# |    time_elapsed    | 2394     |
# |    total timesteps | 191983   |
# | train/             |          |
# |    actor_loss      | -46.2    |
# |    critic_loss     | 7.38     |
# |    ent_coef        | 0.0677   |
# |    ent_coef_loss   | 0.118    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 190982   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 281      |
# |    ep_rew_mean     | 233      |
# | time/              |          |
# |    episodes        | 490      |
# |    fps             | 80       |
# |    time_elapsed    | 2436     |
# |    total timesteps | 195467   |
# | train/             |          |
# |    actor_loss      | -51.6    |
# |    critic_loss     | 2.17     |
# |    ent_coef        | 0.0686   |
# |    ent_coef_loss   | -0.669   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 194466   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 289      |
# |    ep_rew_mean     | 233      |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 80       |
# |    time_elapsed    | 2474     |
# |    total timesteps | 198690   |
# | train/             |          |
# |    actor_loss      | -50.7    |
# |    critic_loss     | 21.2     |
# |    ent_coef        | 0.0631   |
# |    ent_coef_loss   | -0.116   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 197689   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 283      |
# |    ep_rew_mean     | 236      |
# | time/              |          |
# |    episodes        | 510      |
# |    fps             | 80       |
# |    time_elapsed    | 2504     |
# |    total timesteps | 201232   |
# | train/             |          |
# |    actor_loss      | -50.9    |
# |    critic_loss     | 8.95     |
# |    ent_coef        | 0.069    |
# |    ent_coef_loss   | -0.134   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 200231   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 278      |
# |    ep_rew_mean     | 233      |
# | time/              |          |
# |    episodes        | 520      |
# |    fps             | 80       |
# |    time_elapsed    | 2528     |
# |    total timesteps | 203253   |
# | train/             |          |
# |    actor_loss      | -53.2    |
# |    critic_loss     | 3.47     |
# |    ent_coef        | 0.0677   |
# |    ent_coef_loss   | -0.605   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 202252   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 280      |
# |    ep_rew_mean     | 235      |
# | time/              |          |
# |    episodes        | 530      |
# |    fps             | 80       |
# |    time_elapsed    | 2563     |
# |    total timesteps | 206256   |
# | train/             |          |
# |    actor_loss      | -52      |
# |    critic_loss     | 3.5      |
# |    ent_coef        | 0.0728   |
# |    ent_coef_loss   | 0.29     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 205255   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 276      |
# |    ep_rew_mean     | 238      |
# | time/              |          |
# |    episodes        | 540      |
# |    fps             | 80       |
# |    time_elapsed    | 2588     |
# |    total timesteps | 208464   |
# | train/             |          |
# |    actor_loss      | -52.5    |
# |    critic_loss     | 1.98     |
# |    ent_coef        | 0.067    |
# |    ent_coef_loss   | -0.29    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 207463   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 272      |
# |    ep_rew_mean     | 238      |
# | time/              |          |
# |    episodes        | 550      |
# |    fps             | 80       |
# |    time_elapsed    | 2614     |
# |    total timesteps | 210661   |
# | train/             |          |
# |    actor_loss      | -52.3    |
# |    critic_loss     | 2.9      |
# |    ent_coef        | 0.0648   |
# |    ent_coef_loss   | -0.271   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 209660   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 264      |
# |    ep_rew_mean     | 241      |
# | time/              |          |
# |    episodes        | 560      |
# |    fps             | 80       |
# |    time_elapsed    | 2641     |
# |    total timesteps | 212951   |
# | train/             |          |
# |    actor_loss      | -55.4    |
# |    critic_loss     | 3.46     |
# |    ent_coef        | 0.0703   |
# |    ent_coef_loss   | -0.115   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 211950   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 263      |
# |    ep_rew_mean     | 248      |
# | time/              |          |
# |    episodes        | 570      |
# |    fps             | 80       |
# |    time_elapsed    | 2670     |
# |    total timesteps | 215383   |
# | train/             |          |
# |    actor_loss      | -54.7    |
# |    critic_loss     | 9.67     |
# |    ent_coef        | 0.07     |
# |    ent_coef_loss   | -0.219   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 214382   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 256      |
# |    ep_rew_mean     | 253      |
# | time/              |          |
# |    episodes        | 580      |
# |    fps             | 80       |
# |    time_elapsed    | 2695     |
# |    total timesteps | 217597   |
# | train/             |          |
# |    actor_loss      | -54.3    |
# |    critic_loss     | 11.4     |
# |    ent_coef        | 0.0683   |
# |    ent_coef_loss   | 0.606    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 216596   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 244      |
# |    ep_rew_mean     | 255      |
# | time/              |          |
# |    episodes        | 590      |
# |    fps             | 80       |
# |    time_elapsed    | 2721     |
# |    total timesteps | 219819   |
# | train/             |          |
# |    actor_loss      | -58.2    |
# |    critic_loss     | 4.49     |
# |    ent_coef        | 0.0721   |
# |    ent_coef_loss   | -0.523   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 218818   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 233      |
# |    ep_rew_mean     | 257      |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 80       |
# |    time_elapsed    | 2746     |
# |    total timesteps | 221941   |
# | train/             |          |
# |    actor_loss      | -54      |
# |    critic_loss     | 3.2      |
# |    ent_coef        | 0.069    |
# |    ent_coef_loss   | -0.154   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 220940   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 236      |
# |    ep_rew_mean     | 258      |
# | time/              |          |
# |    episodes        | 610      |
# |    fps             | 80       |
# |    time_elapsed    | 2781     |
# |    total timesteps | 224872   |
# | train/             |          |
# |    actor_loss      | -54.5    |
# |    critic_loss     | 3.76     |
# |    ent_coef        | 0.0723   |
# |    ent_coef_loss   | 0.553    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 223871   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 239      |
# |    ep_rew_mean     | 258      |
# | time/              |          |
# |    episodes        | 620      |
# |    fps             | 80       |
# |    time_elapsed    | 2807     |
# |    total timesteps | 227154   |
# | train/             |          |
# |    actor_loss      | -55.5    |
# |    critic_loss     | 1.9      |
# |    ent_coef        | 0.0661   |
# |    ent_coef_loss   | -0.673   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 226153   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 237      |
# |    ep_rew_mean     | 259      |
# | time/              |          |
# |    episodes        | 630      |
# |    fps             | 80       |
# |    time_elapsed    | 2840     |
# |    total timesteps | 229939   |
# | train/             |          |
# |    actor_loss      | -58.1    |
# |    critic_loss     | 4.04     |
# |    ent_coef        | 0.069    |
# |    ent_coef_loss   | -0.0348  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 228938   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 236      |
# |    ep_rew_mean     | 262      |
# | time/              |          |
# |    episodes        | 640      |
# |    fps             | 80       |
# |    time_elapsed    | 2865     |
# |    total timesteps | 232041   |
# | train/             |          |
# |    actor_loss      | -57.1    |
# |    critic_loss     | 2.97     |
# |    ent_coef        | 0.0731   |
# |    ent_coef_loss   | -0.619   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 231040   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 237      |
# |    ep_rew_mean     | 265      |
# | time/              |          |
# |    episodes        | 650      |
# |    fps             | 81       |
# |    time_elapsed    | 2892     |
# |    total timesteps | 234387   |
# | train/             |          |
# |    actor_loss      | -60.2    |
# |    critic_loss     | 2.21     |
# |    ent_coef        | 0.0748   |
# |    ent_coef_loss   | -0.269   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 233386   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 236      |
# |    ep_rew_mean     | 264      |
# | time/              |          |
# |    episodes        | 660      |
# |    fps             | 81       |
# |    time_elapsed    | 2918     |
# |    total timesteps | 236599   |
# | train/             |          |
# |    actor_loss      | -61.1    |
# |    critic_loss     | 6.09     |
# |    ent_coef        | 0.0739   |
# |    ent_coef_loss   | 0.508    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 235598   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 234      |
# |    ep_rew_mean     | 264      |
# | time/              |          |
# |    episodes        | 670      |
# |    fps             | 81       |
# |    time_elapsed    | 2944     |
# |    total timesteps | 238782   |
# | train/             |          |
# |    actor_loss      | -60.2    |
# |    critic_loss     | 2.71     |
# |    ent_coef        | 0.0783   |
# |    ent_coef_loss   | -0.0388  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 237781   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 243      |
# |    ep_rew_mean     | 259      |
# | time/              |          |
# |    episodes        | 680      |
# |    fps             | 81       |
# |    time_elapsed    | 2982     |
# |    total timesteps | 241940   |
# | train/             |          |
# |    actor_loss      | -60.6    |
# |    critic_loss     | 52.8     |
# |    ent_coef        | 0.0798   |
# |    ent_coef_loss   | 0.147    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 240939   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 254      |
# |    ep_rew_mean     | 252      |
# | time/              |          |
# |    episodes        | 690      |
# |    fps             | 81       |
# |    time_elapsed    | 3021     |
# |    total timesteps | 245176   |
# | train/             |          |
# |    actor_loss      | -59.8    |
# |    critic_loss     | 2.88     |
# |    ent_coef        | 0.0812   |
# |    ent_coef_loss   | 0.411    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 244175   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 271      |
# |    ep_rew_mean     | 248      |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 81       |
# |    time_elapsed    | 3069     |
# |    total timesteps | 249015   |
# | train/             |          |
# |    actor_loss      | -63.4    |
# |    critic_loss     | 12.5     |
# |    ent_coef        | 0.0864   |
# |    ent_coef_loss   | -0.236   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 248014   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 277      |
# |    ep_rew_mean     | 241      |
# | time/              |          |
# |    episodes        | 710      |
# |    fps             | 81       |
# |    time_elapsed    | 3112     |
# |    total timesteps | 252568   |
# | train/             |          |
# |    actor_loss      | -61.3    |
# |    critic_loss     | 2.37     |
# |    ent_coef        | 0.0856   |
# |    ent_coef_loss   | 0.204    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 251567   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 276      |
# |    ep_rew_mean     | 237      |
# | time/              |          |
# |    episodes        | 720      |
# |    fps             | 81       |
# |    time_elapsed    | 3138     |
# |    total timesteps | 254767   |
# | train/             |          |
# |    actor_loss      | -59.1    |
# |    critic_loss     | 6.53     |
# |    ent_coef        | 0.0817   |
# |    ent_coef_loss   | 1.25     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 253766   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 267      |
# |    ep_rew_mean     | 229      |
# | time/              |          |
# |    episodes        | 730      |
# |    fps             | 81       |
# |    time_elapsed    | 3159     |
# |    total timesteps | 256622   |
# | train/             |          |
# |    actor_loss      | -63.3    |
# |    critic_loss     | 5.97     |
# |    ent_coef        | 0.0808   |
# |    ent_coef_loss   | -0.833   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 255621   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 269      |
# |    ep_rew_mean     | 232      |
# | time/              |          |
# |    episodes        | 740      |
# |    fps             | 81       |
# |    time_elapsed    | 3187     |
# |    total timesteps | 258977   |
# | train/             |          |
# |    actor_loss      | -60.3    |
# |    critic_loss     | 3.04     |
# |    ent_coef        | 0.0804   |
# |    ent_coef_loss   | 0.167    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 257976   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 266      |
# |    ep_rew_mean     | 232      |
# | time/              |          |
# |    episodes        | 750      |
# |    fps             | 81       |
# |    time_elapsed    | 3211     |
# |    total timesteps | 261029   |
# | train/             |          |
# |    actor_loss      | -59.5    |
# |    critic_loss     | 2.63     |
# |    ent_coef        | 0.0752   |
# |    ent_coef_loss   | 0.128    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 260028   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 273      |
# |    ep_rew_mean     | 229      |
# | time/              |          |
# |    episodes        | 760      |
# |    fps             | 81       |
# |    time_elapsed    | 3245     |
# |    total timesteps | 263869   |
# | train/             |          |
# |    actor_loss      | -55.7    |
# |    critic_loss     | 7.63     |
# |    ent_coef        | 0.0721   |
# |    ent_coef_loss   | 0.15     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 262868   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 277      |
# |    ep_rew_mean     | 224      |
# | time/              |          |
# |    episodes        | 770      |
# |    fps             | 81       |
# |    time_elapsed    | 3275     |
# |    total timesteps | 266456   |
# | train/             |          |
# |    actor_loss      | -52.8    |
# |    critic_loss     | 5.41     |
# |    ent_coef        | 0.0723   |
# |    ent_coef_loss   | 1.33     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 265455   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 267      |
# |    ep_rew_mean     | 228      |
# | time/              |          |
# |    episodes        | 780      |
# |    fps             | 81       |
# |    time_elapsed    | 3301     |
# |    total timesteps | 268681   |
# | train/             |          |
# |    actor_loss      | -57.7    |
# |    critic_loss     | 5.87     |
# |    ent_coef        | 0.0732   |
# |    ent_coef_loss   | -0.146   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 267680   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 257      |
# |    ep_rew_mean     | 232      |
# | time/              |          |
# |    episodes        | 790      |
# |    fps             | 81       |
# |    time_elapsed    | 3327     |
# |    total timesteps | 270911   |
# | train/             |          |
# |    actor_loss      | -58      |
# |    critic_loss     | 12.3     |
# |    ent_coef        | 0.0742   |
# |    ent_coef_loss   | 0.237    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 269910   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 244      |
# |    ep_rew_mean     | 228      |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 81       |
# |    time_elapsed    | 3357     |
# |    total timesteps | 273441   |
# | train/             |          |
# |    actor_loss      | -57.4    |
# |    critic_loss     | 27       |
# |    ent_coef        | 0.0715   |
# |    ent_coef_loss   | -0.494   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 272440   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | 235      |
# | time/              |          |
# |    episodes        | 810      |
# |    fps             | 81       |
# |    time_elapsed    | 3383     |
# |    total timesteps | 275714   |
# | train/             |          |
# |    actor_loss      | -59.5    |
# |    critic_loss     | 3.76     |
# |    ent_coef        | 0.0726   |
# |    ent_coef_loss   | 0.212    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 274713   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 239      |
# |    ep_rew_mean     | 235      |
# | time/              |          |
# |    episodes        | 820      |
# |    fps             | 81       |
# |    time_elapsed    | 3419     |
# |    total timesteps | 278697   |
# | train/             |          |
# |    actor_loss      | -56.2    |
# |    critic_loss     | 7.98     |
# |    ent_coef        | 0.0691   |
# |    ent_coef_loss   | -0.598   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 277696   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 250      |
# |    ep_rew_mean     | 237      |
# | time/              |          |
# |    episodes        | 830      |
# |    fps             | 81       |
# |    time_elapsed    | 3454     |
# |    total timesteps | 281647   |
# | train/             |          |
# |    actor_loss      | -57.6    |
# |    critic_loss     | 3.17     |
# |    ent_coef        | 0.0679   |
# |    ent_coef_loss   | 0.8      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 280646   |
# ---------------------------------
# ...
# |    fps             | 83       |
# |    time_elapsed    | 5397     |
# |    total timesteps | 448089   |
# | train/             |          |
# |    actor_loss      | -76.8    |
# |    critic_loss     | 1.25     |
# |    ent_coef        | 0.0504   |
# |    ent_coef_loss   | -0.791   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 447088   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 196      |
# |    ep_rew_mean     | 282      |
# | time/              |          |
# |    episodes        | 1640     |
# |    fps             | 83       |
# |    time_elapsed    | 5418     |
# |    total timesteps | 449909   |
# | train/             |          |
# |    actor_loss      | -79.8    |
# |    critic_loss     | 10.6     |
# |    ent_coef        | 0.0529   |
# |    ent_coef_loss   | -0.205   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 448908   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | 282      |
# | time/              |          |
# |    episodes        | 1650     |
# |    fps             | 83       |
# |    time_elapsed    | 5440     |
# |    total timesteps | 451765   |
# | train/             |          |
# |    actor_loss      | -80.9    |
# |    critic_loss     | 14.8     |
# |    ent_coef        | 0.0491   |
# |    ent_coef_loss   | -0.0655  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 450764   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | 283      |
# | time/              |          |
# |    episodes        | 1660     |
# |    fps             | 83       |
# |    time_elapsed    | 5463     |
# |    total timesteps | 453741   |
# | train/             |          |
# |    actor_loss      | -80.5    |
# |    critic_loss     | 3.66     |
# |    ent_coef        | 0.0503   |
# |    ent_coef_loss   | -0.217   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 452740   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | 283      |
# | time/              |          |
# |    episodes        | 1670     |
# |    fps             | 83       |
# |    time_elapsed    | 5484     |
# |    total timesteps | 455617   |
# | train/             |          |
# |    actor_loss      | -80.7    |
# |    critic_loss     | 4.28     |
# |    ent_coef        | 0.048    |
# |    ent_coef_loss   | -0.756   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 454616   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 195      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 1680     |
# |    fps             | 83       |
# |    time_elapsed    | 5505     |
# |    total timesteps | 457448   |
# | train/             |          |
# |    actor_loss      | -74.5    |
# |    critic_loss     | 10.7     |
# |    ent_coef        | 0.0494   |
# |    ent_coef_loss   | 0.41     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 456447   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 195      |
# |    ep_rew_mean     | 283      |
# | time/              |          |
# |    episodes        | 1690     |
# |    fps             | 83       |
# |    time_elapsed    | 5528     |
# |    total timesteps | 459424   |
# | train/             |          |
# |    actor_loss      | -80.2    |
# |    critic_loss     | 1.91     |
# |    ent_coef        | 0.0506   |
# |    ent_coef_loss   | 0.0362   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 458423   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 193      |
# |    ep_rew_mean     | 282      |
# | time/              |          |
# |    episodes        | 1700     |
# |    fps             | 83       |
# |    time_elapsed    | 5548     |
# |    total timesteps | 461151   |
# | train/             |          |
# |    actor_loss      | -81.7    |
# |    critic_loss     | 6.31     |
# |    ent_coef        | 0.0479   |
# |    ent_coef_loss   | 0.403    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 460150   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 188      |
# |    ep_rew_mean     | 281      |
# | time/              |          |
# |    episodes        | 1710     |
# |    fps             | 83       |
# |    time_elapsed    | 5570     |
# |    total timesteps | 463013   |
# | train/             |          |
# |    actor_loss      | -78.5    |
# |    critic_loss     | 6.95     |
# |    ent_coef        | 0.0486   |
# |    ent_coef_loss   | 0.259    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 462012   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 186      |
# |    ep_rew_mean     | 281      |
# | time/              |          |
# |    episodes        | 1720     |
# |    fps             | 83       |
# |    time_elapsed    | 5591     |
# |    total timesteps | 464815   |
# | train/             |          |
# |    actor_loss      | -81      |
# |    critic_loss     | 4.23     |
# |    ent_coef        | 0.0519   |
# |    ent_coef_loss   | -0.835   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 463814   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 186      |
# |    ep_rew_mean     | 280      |
# | time/              |          |
# |    episodes        | 1730     |
# |    fps             | 83       |
# |    time_elapsed    | 5612     |
# |    total timesteps | 466706   |
# | train/             |          |
# |    actor_loss      | -78.6    |
# |    critic_loss     | 4.25     |
# |    ent_coef        | 0.0487   |
# |    ent_coef_loss   | -0.575   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 465705   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 186      |
# |    ep_rew_mean     | 282      |
# | time/              |          |
# |    episodes        | 1740     |
# |    fps             | 83       |
# |    time_elapsed    | 5634     |
# |    total timesteps | 468524   |
# | train/             |          |
# |    actor_loss      | -77      |
# |    critic_loss     | 1.66     |
# |    ent_coef        | 0.0464   |
# |    ent_coef_loss   | 0.15     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 467523   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 186      |
# |    ep_rew_mean     | 282      |
# | time/              |          |
# |    episodes        | 1750     |
# |    fps             | 83       |
# |    time_elapsed    | 5655     |
# |    total timesteps | 470367   |
# | train/             |          |
# |    actor_loss      | -76.5    |
# |    critic_loss     | 9.93     |
# |    ent_coef        | 0.0482   |
# |    ent_coef_loss   | 0.956    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 469366   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 185      |
# |    ep_rew_mean     | 281      |
# | time/              |          |
# |    episodes        | 1760     |
# |    fps             | 83       |
# |    time_elapsed    | 5677     |
# |    total timesteps | 472261   |
# | train/             |          |
# |    actor_loss      | -82.4    |
# |    critic_loss     | 2.17     |
# |    ent_coef        | 0.0477   |
# |    ent_coef_loss   | -0.759   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 471260   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 185      |
# |    ep_rew_mean     | 280      |
# | time/              |          |
# |    episodes        | 1770     |
# |    fps             | 83       |
# |    time_elapsed    | 5698     |
# |    total timesteps | 474137   |
# | train/             |          |
# |    actor_loss      | -79.9    |
# |    critic_loss     | 3.91     |
# |    ent_coef        | 0.0502   |
# |    ent_coef_loss   | 0.375    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 473136   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 185      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 1780     |
# |    fps             | 83       |
# |    time_elapsed    | 5719     |
# |    total timesteps | 475948   |
# | train/             |          |
# |    actor_loss      | -83.8    |
# |    critic_loss     | 4.41     |
# |    ent_coef        | 0.0479   |
# |    ent_coef_loss   | -0.595   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 474947   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 184      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 1790     |
# |    fps             | 83       |
# |    time_elapsed    | 5741     |
# |    total timesteps | 477839   |
# | train/             |          |
# |    actor_loss      | -80      |
# |    critic_loss     | 1.21     |
# |    ent_coef        | 0.0462   |
# |    ent_coef_loss   | -0.448   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 476838   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 186      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 1800     |
# |    fps             | 83       |
# |    time_elapsed    | 5763     |
# |    total timesteps | 479724   |
# | train/             |          |
# |    actor_loss      | -78.7    |
# |    critic_loss     | 1.87     |
# |    ent_coef        | 0.0477   |
# |    ent_coef_loss   | 0.255    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 478723   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 187      |
# |    ep_rew_mean     | 280      |
# | time/              |          |
# |    episodes        | 1810     |
# |    fps             | 83       |
# |    time_elapsed    | 5786     |
# |    total timesteps | 481711   |
# | train/             |          |
# |    actor_loss      | -80.3    |
# |    critic_loss     | 5.36     |
# |    ent_coef        | 0.0476   |
# |    ent_coef_loss   | -0.00499 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 480710   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 1820     |
# |    fps             | 83       |
# |    time_elapsed    | 5811     |
# |    total timesteps | 483824   |
# | train/             |          |
# |    actor_loss      | -80.4    |
# |    critic_loss     | 3.64     |
# |    ent_coef        | 0.0499   |
# |    ent_coef_loss   | 0.0973   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 482823   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | 280      |
# | time/              |          |
# |    episodes        | 1830     |
# |    fps             | 83       |
# |    time_elapsed    | 5833     |
# |    total timesteps | 485709   |
# | train/             |          |
# |    actor_loss      | -80.5    |
# |    critic_loss     | 46.2     |
# |    ent_coef        | 0.0473   |
# |    ent_coef_loss   | -0.432   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 484708   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | 278      |
# | time/              |          |
# |    episodes        | 1840     |
# |    fps             | 83       |
# |    time_elapsed    | 5859     |
# |    total timesteps | 487969   |
# | train/             |          |
# |    actor_loss      | -79.5    |
# |    critic_loss     | 14.3     |
# |    ent_coef        | 0.0485   |
# |    ent_coef_loss   | -0.118   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 486968   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 195      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 1850     |
# |    fps             | 83       |
# |    time_elapsed    | 5881     |
# |    total timesteps | 489872   |
# | train/             |          |
# |    actor_loss      | -80.9    |
# |    critic_loss     | 1.51     |
# |    ent_coef        | 0.0439   |
# |    ent_coef_loss   | -0.101   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 488871   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 1860     |
# |    fps             | 83       |
# |    time_elapsed    | 5902     |
# |    total timesteps | 491677   |
# | train/             |          |
# |    actor_loss      | -81.3    |
# |    critic_loss     | 3.34     |
# |    ent_coef        | 0.0494   |
# |    ent_coef_loss   | -0.0784  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 490676   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 1870     |
# |    fps             | 83       |
# |    time_elapsed    | 5923     |
# |    total timesteps | 493490   |
# | train/             |          |
# |    actor_loss      | -82.4    |
# |    critic_loss     | 5.46     |
# |    ent_coef        | 0.0495   |
# |    ent_coef_loss   | -0.259   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 492489   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 1880     |
# |    fps             | 83       |
# |    time_elapsed    | 5945     |
# |    total timesteps | 495369   |
# | train/             |          |
# |    actor_loss      | -82.9    |
# |    critic_loss     | 2.97     |
# |    ent_coef        | 0.0472   |
# |    ent_coef_loss   | 0.409    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 494368   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 199      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 1890     |
# |    fps             | 83       |
# |    time_elapsed    | 5972     |
# |    total timesteps | 497698   |
# | train/             |          |
# |    actor_loss      | -79.5    |
# |    critic_loss     | 4.74     |
# |    ent_coef        | 0.0482   |
# |    ent_coef_loss   | 1.49     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 496697   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 198      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 1900     |
# |    fps             | 83       |
# |    time_elapsed    | 5994     |
# |    total timesteps | 499534   |
# | train/             |          |
# |    actor_loss      | -81.8    |
# |    critic_loss     | 6.57     |
# |    ent_coef        | 0.0486   |
# |    ent_coef_loss   | 0.184    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 498533   |
# ---------------------------------

# %%
def plot_log(df_path):

    with open(df_path, "rt") as f:
        _ = f.readline()
        df = pd.read_csv(f)
        df.sort_values("t", inplace=True)
        df.reset_index(inplace=True)

    # compute rolling avg and std
    sma_y = df['r'].rolling(100, min_periods=1).mean()
    std_y = df['r'].rolling(100, min_periods=1).std()
    
    # plot with seaborn
    sns.set()
    fig, ax = plt.subplots(figsize=(10,10))
    ax.set_xlabel('Timesteps')
    ax.set_ylabel('Reward')
    clrs = sns.color_palette("husl", 8)

    true_x = (ONLINE_STEPS // max(df['index'])) * df['index']

    # fill standard deviation
    ax.plot(true_x, sma_y, c=clrs[0])
    ax.fill_between(true_x, sma_y-std_y,  sma_y+std_y, 
                    alpha=0.3, facecolor=clrs[0]) 
    plt.savefig(SAVE_DIR+ENV_NAME+'.reward_history.png', 
                dpi=300, pad_inches=0)
    plt.show()

plot_log(SAVE_DIR+ENV_NAME+'.monitor.csv')

# %%
def get_expert_buf(num=100000):
    buf = {'observation':[], 'action':[], 'terminal':[], 'reward':[]}
    obs = env.reset()
    for _ in range(num):
        action, _states = model.predict(obs)
        buf['observation'].append(obs)
        buf['action'].append(action)
        obs, reward, done, info = env.step(action)
        buf['terminal'].append(done)
        buf['reward'].append(reward)
        if done:
            obs = env.reset()
    buf['observation'] = np.stack(buf['observation'])
    buf['action'] = np.stack(buf['action'])
    buf['reward'] = np.stack(buf['reward'])
    
    return buf

expert_data = get_expert_buf()
with open(SAVE_DIR+ENV_NAME+'.expert_data.pkl', 'wb') as f:
    pkl.dump(expert_data, f)
